# %% [markdown]
# Student: Michael Menjares

# %% [markdown]
# # Part 1&2

# %% [markdown]
# **Part 1**
#
# Create a notebook where you have uploaded and shown the .head() of each of your data sets. For each of the proposed datasets, include the following information in text cells:
#
# 1. Source of data
#
# 2. Brief description of data
#
# 3. What is the target?
#
# 4. What does one row represent? (A person?  A business?  An event? A product?)
#
# 5. Is this a classification or regression problem?
#
# 6. How many features does the data have?
#
# 7. How many rows are in the dataset?
#
# 8. What, if any, challenges do you foresee in cleaning, exploring, or modeling this dataset?
#
# Create a NEW GitHub repository for this project, with a readme, and add your notebook to that new repository.

# %% [markdown]
# **Part 2**
# - Deleted unnecessary columns.
# - Deleted duplicate rows.
# - Identified and addressed missing values.
# - Identified and corrected inconsistencies in data for categorical values (i.e. Cat, cat, cats).
# - Produced univariate visuals for the target and all features.
# - Identified outliers.
# - Clearly commented all of your cleaning steps and described any decisions you made.
# - Commit your file to your Github repository and submit the link below.

# %% [markdown]
# Dataset contains 14 features such as individual’s education level, age, gender, occupation and explores the possibility in predicting whether an individual will make more than $50k in annual income based on these features. The dataset has 48,842 rows and each row represents an individual. This is a classification problem since the target is the income column which has two classes: <=50K and >50K. As far as a challenge, some of the data has a '?' which is pressumed to be a NaN or missing value.
#
# source: https://www.kaggle.com/datasets/wenruliu/adult-income-dataset

# %% [markdown]
# ## Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.compose import make_column_selector, make_column_transformer

from lightgbm import LGBMClassifier
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline

from sklearn.metrics import (roc_auc_score, ConfusionMatrixDisplay, 
                             PrecisionRecallDisplay, RocCurveDisplay, 
                             f1_score, accuracy_score, precision_score,
                             recall_score, classification_report)

# Keras
from tensorflow.keras import Sequential
from tensorflow.keras import metrics
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from keras import regularizers

# %%
url = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vStYRY6SXzBSdI6psSMrZLiTc2vteGZbPv57tyZaE4csMWbQSa9MJuRXJJXo2kYa-hFuppkA8mtfhli/pub?gid=488173702&single=true&output=csv'
df_original = pd.read_csv(url)
df = df_original.copy()
df.head(20)
# Out:
#     age         workclass  fnlwgt     education  educational-num  \
# 0    25           Private  226802          11th                7
# 1    38           Private   89814       HS-grad                9
# 2    28         Local-gov  336951    Assoc-acdm               12
# 3    44           Private  160323  Some-college               10
# 4    18                 ?  103497  Some-college               10
# 5    34           Private  198693          10th                6
# 6    29                 ?  227026       HS-grad                9
# 7    63  Self-emp-not-inc  104626   Prof-school               15
# 8    24           Private  369667  Some-college               10
# 9    55           Private  104996       7th-8th                4
# 10   65           Private  184454       HS-grad                9
# 11   36       Federal-gov  212465     Bachelors               13
# 12   26           Private   82091       HS-grad                9
# 13   58                 ?  299831       HS-grad                9
# 14   48           Private  279724       HS-grad                9
# 15   43           Private  346189       Masters               14
# 16   20         State-gov  444554  Some-college               10
# 17   43           Private  128354       HS-grad                9
# 18   37           Private   60548       HS-grad                9
# 19   40           Private   85019     Doctorate               16
#
#         marital-status         occupation   relationship                race  \
# 0        Never-married  Machine-op-inspct      Own-child               Black
# 1   Married-civ-spouse    Farming-fishing        Husband               White
# 2   Married-civ-spouse    Protective-serv        Husband               White
# 3   Married-civ-spouse  Machine-op-inspct        Husband               Black
# 4        Never-married                  ?      Own-child               White
# 5        Never-married      Other-service  Not-in-family               White
# 6        Never-married                  ?      Unmarried               Black
# 7   Married-civ-spouse     Prof-specialty        Husband               White
# 8        Never-married      Other-service      Unmarried               White
# 9   Married-civ-spouse       Craft-repair        Husband               White
# 10  Married-civ-spouse  Machine-op-inspct        Husband               White
# 11  Married-civ-spouse       Adm-clerical        Husband               White
# 12       Never-married       Adm-clerical  Not-in-family               White
# 13  Married-civ-spouse                  ?        Husband               White
# 14  Married-civ-spouse  Machine-op-inspct        Husband               White
# 15  Married-civ-spouse    Exec-managerial        Husband               White
# 16       Never-married      Other-service      Own-child               White
# 17  Married-civ-spouse       Adm-clerical           Wife               White
# 18             Widowed  Machine-op-inspct      Unmarried               White
# 19  Married-civ-spouse     Prof-specialty        Husband  Asian-Pac-Islander
#
#     gender  capital-gain  capital-loss  hours-per-week native-country income
# 0     Male             0             0              40  United-States  <=50K
# 1     Male             0             0              50  United-States  <=50K
# 2     Male             0             0              40  United-States   >50K
# 3     Male          7688             0              40  United-States   >50K
# 4   Female             0             0              30  United-States  <=50K
# 5     Male             0             0              30  United-States  <=50K
# 6     Male             0             0              40  United-States  <=50K
# 7     Male          3103             0              32  United-States   >50K
# 8   Female             0             0              40  United-States  <=50K
# 9     Male             0             0              10  United-States  <=50K
# 10    Male          6418             0              40  United-States   >50K
# 11    Male             0             0              40  United-States  <=50K
# 12  Female             0             0              39  United-States  <=50K
# 13    Male             0             0              35  United-States  <=50K
# 14    Male          3103             0              48  United-States   >50K
# 15    Male             0             0              50  United-States   >50K
# 16    Male             0             0              25  United-States  <=50K
# 17  Female             0             0              30  United-States  <=50K
# 18  Female             0             0              20  United-States  <=50K
# 19    Male             0             0              45              ?   >50K

# %%
df.sort_values(by='educational-num', ascending=True)
df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %% [markdown]
# ## Data Manipulation

# %%
#remove rows that have '?' anywhere in df
value = '?'
df = df[~df.isin([value]).any(axis=1)]

# %%
#remove rows that have 'Without-pay' anywhere in df
value = 'Without-pay'
df = df[~df.isin([value]).any(axis=1)]

# %%
df['workclass'].value_counts()
# Out:
# Private             33307
# Self-emp-not-inc     3796
# Local-gov            3100
# State-gov            1946
# Self-emp-inc         1646
# Federal-gov          1406
# Name: workclass, dtype: int64

# %%
not_gov = ['Private','Self-emp-not-inc','Self-emp-inc']
gov = ['Local-gov','State-gov','Federal-gov']
df['workclass'][df['workclass'].isin(not_gov)] = 0
df['workclass'][df['workclass'].isin(gov)] = 1
df.rename(columns={'workclass': 'IsGov'}, inplace=True)
# Out:
# C:\Users\mmenj\AppData\Local\Temp\ipykernel_24508\2222147724.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['workclass'][df['workclass'].isin(gov)] = 1

# %%
df['IsGov'].value_counts(dropna=False)
# Out:
# 0    38749
# 1     6452
# Name: IsGov, dtype: int64

# %%
df['IsGov'] = df['IsGov'].astype(int)

# %%
df['age'] = (df['age'] // 10) * 10

# %% [markdown]
# ## Split

# %%
target = ['income']
drop_cols = ['fnlwgt','education']

drop_cols = target + drop_cols

df[target] = df[target].replace({'>50K': 1, '<=50K': 0})


y = df[target]
X = df.drop(columns = drop_cols)

X['net-capital'] = X['capital-gain'] - X['capital-loss']
X = X.drop(['capital-gain', 'capital-loss'], axis=1)


X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

print(f'Target Values:\n{y.head()}\n\nFeatures:')

X.head()
# Out:
# Target Values:
#    income
# 0       0
# 1       0
# 2       1
# 3       1
# 5       0
#
# Features:
#    age  IsGov  educational-num      marital-status         occupation  \
# 0   20      0                7       Never-married  Machine-op-inspct
# 1   30      0                9  Married-civ-spouse    Farming-fishing
# 2   20      1               12  Married-civ-spouse    Protective-serv
# 3   40      0               10  Married-civ-spouse  Machine-op-inspct
# 5   30      0                6       Never-married      Other-service
#
#     relationship   race gender  hours-per-week native-country  net-capital
# 0      Own-child  Black   Male              40  United-States            0
# 1        Husband  White   Male              50  United-States            0
# 2        Husband  White   Male              40  United-States            0
# 3        Husband  Black   Male              40  United-States         7688
# 5  Not-in-family  White   Male              30  United-States            0

# %% [markdown]
# Decided to drop fnlwgt which is a number created by surveyors and felt did not have a correlation to target. Also dropped education column since education num is the same data as education-num but in integer form.

# %% [markdown]
# ## Clean Data

# %% [markdown]
# Duplicates

# %%
print(f'{df.duplicated().sum()} duplicates before drop')
df.drop_duplicates(inplace = True)
print(f'Duplicates dropped\n{df.duplicated().sum()} duplicates after drop')
# Out:
# 139 duplicates before drop
# Duplicates dropped
# 0 duplicates after drop

# %% [markdown]
# Missing Data

# %%
print(f'{df.isna().sum().sum()} of the {len(df)} entries have missing values.')
print(f'\nThis is {round(df.isna().sum().sum()/len(df)*100)}% of the entries')
print(f'\nMissing Entries by Column:\n{df.isna().sum()}')
# Out:
# 0 of the 45062 entries have missing values.
#
# This is 0% of the entries
#
# Missing Entries by Column:
# age                0
# IsGov              0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %% [markdown]
# even though shows no missing values, a few columns have values marked '?' which is assumed to be unknown or a missing value.

# %% [markdown]
# Check Datatypes and Inconsistent Values

# %%
print(f'X Data Types:\n\n{X.dtypes}\n')
print(f'y Data Types:\n\n{y.dtypes}')
# Out:
# X Data Types:
#
# age                 int64
# IsGov               int32
# educational-num     int64
# marital-status     object
# occupation         object
# relationship       object
# race               object
# gender             object
# hours-per-week      int64
# native-country     object
# net-capital         int64
# dtype: object
#
# y Data Types:
#
# income    int64
# dtype: object

# %%
X.head()
# Out:
#    age  IsGov  educational-num      marital-status         occupation  \
# 0   20      0                7       Never-married  Machine-op-inspct
# 1   30      0                9  Married-civ-spouse    Farming-fishing
# 2   20      1               12  Married-civ-spouse    Protective-serv
# 3   40      0               10  Married-civ-spouse  Machine-op-inspct
# 5   30      0                6       Never-married      Other-service
#
#     relationship   race gender  hours-per-week native-country  net-capital
# 0      Own-child  Black   Male              40  United-States            0
# 1        Husband  White   Male              50  United-States            0
# 2        Husband  White   Male              40  United-States            0
# 3        Husband  Black   Male              40  United-States         7688
# 5  Not-in-family  White   Male              30  United-States            0

# %%
pd.set_option("display.max_rows", None)
for x in X.columns:
  print(X[x].value_counts(dropna=False), '\n')
# Out:
# 30    12361
# 20    10989
# 40    10304
# 50     6261
# 60     2507
# 10     2049
# 70      587
# 80       97
# 90       46
# Name: age, dtype: int64
#
# 0    38749
# 1     6452
# Name: IsGov, dtype: int64
#
# 9     14769
# 10     9896
# 13     7570
# 14     2514
# 11     1959
# 7      1619
# 12     1505
# 6      1223
# 4       821
# 15      785
# 5       676
# 8       577
# 16      544
# 3       449
# 2       222
# 1        72
# Name: educational-num, dtype: int64
#
# Married-civ-spouse       21042
# Never-married            14592
# Divorced                  6297
# Separated                 1411
# Widowed                   1276
# Married-spouse-absent      551
# Married-AF-spouse           32
# Name: marital-status, dtype: int64
#
# Craft-repair         6019
# Prof-specialty       6008
# Exec-managerial      5983
# Adm-clerical         5537
# Sales                5407
# Other-service        4806
# Machine-op-inspct    2968
# Transport-moving     2315
# Handlers-cleaners    2044
# Farming-fishing      1472
# Tech-support         1420
# Protective-serv       976
# Priv-house-serv       232
# Armed-Forces           14
# Name: occupation, dtype: int64
#
# Husband           18658
# Not-in-family     11702
# Own-child          6618
# Unmarried          4786
# Wife               2088
# Other-relative     1349
# Name: relationship, dtype: int64
#
# White                 38884
# Black                  4227
# Asian-Pac-Islander     1302
# Amer-Indian-Eskimo      435
# Other                   353
# Name: race, dtype: int64
#
# Male      30513
# Female    14688
# Name: gender, dtype: int64
#
# 40    21353
# 50     4092
# 45     2601
# 60     2084
# 35     1776
# 20     1599
# 30     1466
# 55     1019
# 25      818
# 48      733
# 38      681
# 15      519
# 70      418
# 32      371
# 65      348
# 10      330
# 42      326
# 36      308
# 24      304
# 44      301
# 16      252
# 37      236
# 43      219
# 52      200
# 12      200
# 80      189
# 8       152
# 56      133
# 46      127
# 28      123
# 99      123
# 18      112
# 75      100
# 72       97
# 47       82
# 84       65
# 39       62
# 5        60
# 6        59
# 33       59
# 54       58
# 22       56
# 41       56
# 4        47
# 34       47
# 21       41
# 14       41
# 90       41
# 17       40
# 27       39
# 58       37
# 26       37
# 49       36
# 3        35
# 53       34
# 23       34
# 7        32
# 2        24
# 9        24
# 62       23
# 13       22
# 66       22
# 64       21
# 51       20
# 19       19
# 57       19
# 85       17
# 11       16
# 68       16
# 63       14
# 98       14
# 78       13
# 31       12
# 29       12
# 1        12
# 77        9
# 96        9
# 59        6
# 67        6
# 86        4
# 76        4
# 61        4
# 88        4
# 89        3
# 81        3
# 91        3
# 74        3
# 73        3
# 92        3
# 97        2
# 95        2
# 79        1
# 69        1
# 87        1
# 94        1
# 82        1
# Name: hours-per-week, dtype: int64
#
# United-States                 41272
# Mexico                          903
# Philippines                     282
# Germany                         193
# Puerto-Rico                     175
# Canada                          163
# El-Salvador                     147
# India                           147
# Cuba                            133
# England                         119
# China                           113
# Jamaica                         103
# South                           101
# Italy                           100
# Dominican-Republic               97
# Japan                            89
# Guatemala                        86
# Vietnam                          83
# Columbia                         82
# Poland                           81
# Haiti                            69
# Portugal                         62
# Iran                             56
# Taiwan                           55
# Greece                           49
# Nicaragua                        48
# Peru                             45
# Ecuador                          43
# France                           36
# Ireland                          36
# Thailand                         29
# Hong                             28
# Cambodia                         26
# Trinadad&Tobago                  26
# Yugoslavia                       23
# -2163         1
# -1870         1
# -1421         1
#  7262         1
#  1731         1
#  2387         1
# Name: net-capital, dtype: int64

# %%
X.dtypes
# Out:
# age                 int64
# IsGov               int32
# educational-num     int64
# marital-status     object
# occupation         object
# relationship       object
# race               object
# gender             object
# hours-per-week      int64
# native-country     object
# net-capital         int64
# dtype: object

# %% [markdown]
# ## EDA

# %%
X.describe()
# Out:
#                 age         IsGov  educational-num  hours-per-week  \
# count  45201.000000  45201.000000     45201.000000    45201.000000
# mean      34.063848      0.142740        10.119002       40.941262
# std       13.559449      0.349812         2.553043       12.004178
# min       10.000000      0.000000         1.000000        1.000000
# 25%       20.000000      0.000000         9.000000       40.000000
# 50%       30.000000      0.000000        10.000000       40.000000
# 75%       40.000000      0.000000        13.000000       45.000000
# max       90.000000      1.000000        16.000000       99.000000
#
#         net-capital
# count  45201.000000
# mean    1013.196124
# std     7532.005106
# min    -4356.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max    99999.000000

# %%
col_name = 'age'
ax = sns.histplot(data = X, x = col_name,bins=range(min(X[col_name]), max(X[col_name]) + 1))
plt.title(f'Distribution of {col_name}')
plt.show()
print(f'the ages are skewed to the left and peak between 20 and 40 years old')
# Out:
# the ages are skewed to the left and peak between 20 and 40 years old

# %%
col_name = 'educational-num'
ax = sns.histplot(data = X, x = col_name,bins=range(min(X[col_name]), max(X[col_name]) + 1))
plt.title(f'Distribution of {col_name}')
plt.show()
print(f'the education levels skew to the right and most frequent levels are 10,11,14 which are some-college, assocociates or vocational, and masters')
# Out:
# the education levels skew to the right and most frequent levels are 10,11,14 which are some-college, assocociates or vocational, and masters

# %%
col_name = 'marital-status'
sns.countplot(x=col_name, data=X)
plt.title(f'Count of {col_name}')
sns.set(rc={'figure.figsize':(7,5)})
plt.xticks(rotation=45, fontsize=10)
plt.xlabel(col_name)
plt.ylabel('Count')
plt.show()
print('Most are married with a civilian spouse or never married')
# Out:
# Most are married with a civilian spouse or never married

# %%
col_name = 'occupation'
sns.countplot(x=col_name, data=X)
plt.title(f'Count of {col_name}')
sns.set(rc={'figure.figsize':(7,5)})
plt.xticks(rotation=45, fontsize=10)
plt.xlabel(col_name)
plt.ylabel('Count')
plt.show()

# %%
col_name = 'relationship'
sns.countplot(x=col_name, data=X)
plt.title(f'Count of {col_name}')
sns.set(rc={'figure.figsize':(7,5)})
plt.xticks(rotation=45, fontsize=10)
plt.xlabel(col_name)
plt.ylabel('Count')
plt.show()
print('Most common relationship is husband of household or not in family')
# Out:
# Most common relationship is husband of household or not in family

# %%
col_name = 'gender'
sns.countplot(x=col_name, data=X)
plt.title(f'Count of {col_name}')
sns.set(rc={'figure.figsize':(7,5)})
plt.xticks(rotation=45, fontsize=10)
plt.xlabel(col_name)
plt.ylabel('Count')
plt.show()
print('about twice as many males than females in the dataset')
# Out:
# about twice as many males than females in the dataset

# %% [markdown]
# # Part 3
# 1. For this part of the project, you will continue your data exploration by:
#
#     - Identifying any moderate or strong correlations between your target and your features and/or between one feature and another using a correlation heatmap.
#     - Creating multivariate (multiple variables) exploratory visualizations to further understand your data and search for trends.
#
#
# 2. Then, choose two visualizations from your analysis that demonstrate key trends you found that will be of interest to a stakeholder. These visuals should be reporting quality with titles, labels, and a short explanation of the trend. Be sure to explain in a text cell the insight associated with each visual. Both of these visualizations should be easily understood by a non-technical audience (Neither of these should be histograms, boxplots, or correlation plots).
#
#     - These plots should be so simple, and so easy to read, that a 6th grader could understand them in less than 10 seconds without asking questions.  They don't need to be fancy, they need to CLEARLY show an interesting trend or correlation between features in your data.

# %%
X['net-capital'].value_counts()
# Out:
#  0        39274
#  15024      498
#  7688       391
#  7298       351
# -1902       294
# -1977       246
#  99999      229
# -1887       227
#  3103       146
#  5178       137
#  5013       116
#  4386       102
#  3325        81
#  8614        78
#  2174        72
# -2415        68
# -1485        65
# -1848        65
#  10520       64
#  4650        62
# -1876        59
# -1590        58
# -1740        57
#  27828       56
#  4064        52
#  3137        50
# -1672        49
#  14084       47
#  20051       44
#  594         42
# -1741        42
#  3908        41
#  6849        41
# -1602        40
#  13550       40
# -1564        40
#  2829        40
# -2258        39
# -1980        36
#  14344       34
#  4787        34
# -1669        34
# -1719        33
# -1408        32
# -2001        32
#  1055        31
# -2002        31
#  3411        30
#  3464        30
# -2051        29
#  2597        29
# -1579        29
#  4101        28
#  2176        28
#  2885        28
#  2202        27
# -1974        27
#  4865        24
# -2339        24
# -1504        23
#  2407        23
#  9386        23
#  1506        23
# -1628        22
#  4416        22
# -1721        22
# -2377        21
#  4508        21
# -2444        20
#  3674        20
#  2354        20
# -2179        19
#  2580        19
#  5455        18
# -1762        18
#  2907        17
# -625         17
# -2559        17
#  3942        16
#  10605       16
# -2205        16
#  2463        15
#  6497        15
# -2057        15
#  25236       14
#  6418        14
#  3781        14
#  7430        14
#  2635        13
#  1151        13
# -2042        12
# -2824        12
#  2977        11
# -1092        11
# -1340        11
#  2105        11
# -1617        11
# -1651        10
# -2392        10
# -1380        10
#  2964        10
#  914         10
# -1573        10
#  4934        10
#  3471        10
#  15020       10
#  6514         9
#  1471         9
# -1726         9
#  1831         9
# -1594         9
#  2653         9
# -2246         8
#  1848         8
# -1668         8
#  3887         8
#  2290         8
# -2174         8
#  114          8
#  1797         8
#  10566        8
#  15831        8
#  3818         8
# -2231         7
#  5721         7
#  7443         7
#  3273         7
#  2414         6
# -880          6
# -2206         5
#  5556         5
# -2603         5
#  2036         5
#  1409         5
# -213          5
#  9562         5
#  2329         5
#  2346         5
# -2129         5
# -2547         5
#  3418         5
#  1086         5
# -1258         5
# -323          5
#  3456         5
#  4687         4
#  25124        4
#  11678        4
# -3004         4
#  2538         4
# -2472         4
#  6767         4
# -3770         4
#  991          4
# -1825         4
#  4931         4
# -1138         4
# -653          4
# -2238         4
#  34095        4
#  1424         4
#  6723         4
#  1455         3
# -1411         3
# -2149         3
#  2050         3
#  2228         3
#  2936         3
#  6360         3
# -1429         3
# -2267         3
#  2062         3
# -1944         3
#  7896         3
#  41310        3
# -1735         3
# -3900         2
# -810          2
#  2961         2
#  18481        2
# -2457         2
# -1648         2
# -974          2
# -2282         2
#  5060         2
# -1755         2
# -3683         2
#  2009         2
#  3432         2
# -2352         2
# -2754         2
# -1816         2
#  6097         2
#  1264         2
# -2467         2
# -3175         2
# -1844         2
# -1510         2
#  1173         2
#  401          2
#  7978         2
#  2993         2
# -2080         1
#  1639         1
# -419          1
# -2201         1
# -155          1
# -1911         1
# -4356         1
# -1539         1
#  22040        1
# -2163         1
# -1870         1
# -1421         1
#  7262         1
#  1731         1
#  2387         1
# Name: net-capital, dtype: int64

# %%
corr = X.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr, cmap='RdBu', vmin=-1, vmax=1, annot = True);
# Out:
# C:\Users\mmenj\AppData\Local\Temp\ipykernel_24508\4293495446.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = X.corr()

# %%
sns.pairplot(X);

# %% [markdown]
# No obvious pattern or correlation between columns

# %%
def groupby_plot(groupby, groupwhat):
    means = X.groupby(groupby)[groupwhat].mean().sort_values(ascending=False)
    fig, ax = plt.subplots(figsize=(20,10))
    ax = sns.barplot(data=X,x=groupby, y = groupwhat, order = means.index)
    plt.xticks()
    ax.set_title(f'Average {groupwhat} vs. {groupby}', fontsize = 20, fontweight = 'bold');
    ax.set_xlabel(groupby, fontsize = 15, fontweight = 'bold')
    ax.set_ylabel(groupwhat, fontsize = 15, fontweight = 'bold');

# %%
groupby_plot('educational-num','net-capital')

# %% [markdown]
# Bachelors or higher (13+) have the top 4 spots for average net capital

# %%
plt.savefig('Net_Capital_vs_Education.png')

# %%
groupby_plot('occupation','educational-num')

# %%
groupby_plot('occupation','net-capital')

# %% [markdown]
# # Part 4
# **Modeling**
#
# - Ensure that you complete the appropriate pre-processing steps.
# - Fit and evaluate multiple types of models on your data.
#     - Evaluate each model with multiple appropriate metrics on BOTH the train and test data.
#     - Use GridSearchCV to tune some of the hyperparameters of each model.
#     - Display the metrics of your best tuned version of each model type.
# - Try feature engineering techniques or PCA to engineer your dataset to see how this impacts your modeling results.
#     - We encourage you to try multiple techniques depending on your data!
# - Choose your "production" model and justify this decision using the metrics most important to your business problem.
# - Go back through your code and ensure that you have provided clear comments (remember this is for your portfolio!).
#
# **Readme**
#
# - Create a README.md file in your GitHub repository.  This README should include:
#     - Your business problem and stakeholders
#     - The source of your data
#     - A description of your data
#     - 2 analytical insights from your data analysis.
#         - You can use the 2 plots from Project 2, part 3 for this!
#         - They should include visualizations AND written interpretations
#     - The metrics for your best model
#     - A description of how well your model would solve your business problem
#     - A summary with at least 2 recommendations for your stakeholders, based on your model performance AND analytical findings.

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45201 entries, 0 to 48841
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              45201 non-null  int64
#  1   IsGov            45201 non-null  int32
#  2   educational-num  45201 non-null  int64
#  3   marital-status   45201 non-null  object
#  4   occupation       45201 non-null  object
#  5   relationship     45201 non-null  object
#  6   race             45201 non-null  object
#  7   gender           45201 non-null  object
#  8   hours-per-week   45201 non-null  int64
#  9   native-country   45201 non-null  object
#  10  net-capital      45201 non-null  int64
# dtypes: int32(1), int64(4), object(6)
# memory usage: 4.0+ MB

# %% [markdown]
# ## Preprocessing

# %%
num_selector = make_column_selector(dtype_include = 'number')
cat_selector = make_column_selector(dtype_include = 'object')

scaler = StandardScaler()
ohe = OneHotEncoder(sparse=False, handle_unknown = 'ignore')
pca95 = PCA(0.95)

num_tuple = (scaler, num_selector)
cat_tuple = (ohe, cat_selector)

cols_transformer = make_column_transformer(num_tuple,cat_tuple, remainder = 'drop')

# %%
X_train_proc = cols_transformer.transform(X_train)
X_test_proc =  cols_transformer.transform(X_test)

# %% [markdown]
# ## Modeling

# %%
## Create a function to display the classification metrics of a model
def classification_metrics(model, X_test=X_test, y_test=y_test, label='Test Data', 
                             figsize=(15,5), normalize='true',
                             cmap='Greens', thresh=.5): 
                             
    fig, axes = plt.subplots(1,2, figsize=figsize)

    ## Get the predictions
    y_proba = model.predict_proba(X_test)
    y_pred = [1 if x[1] > thresh else 0 for x in y_proba]
    
    ## Print classification report for the test data (and make it pretty!)
    print('---'*20)
    print(f"[i] CLASSIFICATION REPORT FOR: {label}")
    print('---'*20)

    print(classification_report(y_test, y_pred))

    ConfusionMatrixDisplay.from_predictions(y_test,y_pred, 
                normalize=normalize, cmap=cmap,              
                ax=axes[0])    
    
    RocCurveDisplay.from_estimator(model, X_test, y_test,
                                   ax=axes[1])
    plt.plot([0, 1], [0, 1], ls = '--', label = 'Baseline (AUC = 0.5)')
    plt.title(f'ROC AUC for {label}')
    plt.legend(); 
    plt.show()

# %% [markdown]
# ### Random Forest

# %% [markdown]
# #### Base

# %%
model = RandomForestClassifier(random_state=42)
model_pipe = make_pipeline(cols_transformer,model)

# %%
# %%time
model_pipe.fit(X_train,y_train)
# Out:
# C:\Users\mmenj\anaconda3\envs\dojo-env\lib\site-packages\sklearn\pipeline.py:382: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# CPU times: total: 3.89 s
# Wall time: 3.98 s
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('standardscaler',
#                                                   StandardScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000001D09A00D640>),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000001D098AFFD90>)])),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(random_state=42))])

# %%
est_depths = [estimator.get_depth() for estimator in model_pipe.named_steps['randomforestclassifier'].estimators_]
print(f'The max depth of base Random Forest Classifier is {max(est_depths)}')

n_estimators = model_pipe.named_steps['randomforestclassifier'].n_estimators

print("Number of Estimators: ", n_estimators)

min_depth = np.min(est_depths)
mean_depth = np.mean(est_depths)
median_depth = np.median(est_depths)
mode_depth = np.argmax(np.bincount(est_depths))

print("Mean Depth: ", mean_depth)
print("Median Depth: ", median_depth)
print("Mode Depth: ", mode_depth)
print("Min Depth: ", min_depth)
# Out:
# The max depth of base Random Forest Classifier is 64
# Number of Estimators:  100
# Mean Depth:  52.87
# Median Depth:  53.0
# Mode Depth:  54
# Min Depth:  39

# %%
# %%time
preds = model_pipe.predict(X_test)
# Out:
# CPU times: total: 297 ms
# Wall time: 362 ms

# %%
print('Training accuracy:', model_pipe.score(X_train, y_train))
print('Testing accuracy:', model_pipe.score(X_test, y_test))
# Out:
# Training accuracy: 0.9670417294232303
# Testing accuracy: 0.8348688873139617

# %%
classification_metrics(model_pipe)
# Out:
# ------------------------------------------------------------
# [i] CLASSIFICATION REPORT FOR: Test Data
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.87      0.91      0.89      8481
#            1       0.70      0.60      0.64      2807
#
#     accuracy                           0.83     11288
#    macro avg       0.78      0.76      0.77     11288
# weighted avg       0.83      0.83      0.83     11288

# %%
model_pipe.get_params()
# Out:
# {'memory': None,
#  'steps': [('columntransformer',
#    ColumnTransformer(transformers=[('standardscaler', StandardScaler(),
#                                     <sklearn.compose._column_transformer.make_column_selector object at 0x000001D09A00D640>),
#                                    ('onehotencoder',
#                                     OneHotEncoder(handle_unknown='ignore',
#                                                   sparse=False),
#                                     <sklearn.compose._column_transformer.make_column_selector object at 0x000001D098AFFD90>)])),
#   ('randomforestclassifier', RandomForestClassifier(random_state=42))],
#  'verbose': False,
#  'columntransformer': ColumnTransformer(transformers=[('standardscaler', StandardScaler(),
#                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000001D09A00D640>),
#                                  ('onehotencoder',
#                                   OneHotEncoder(handle_unknown='ignore',
#                                                 sparse=False),
#                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000001D098AFFD90>)]),
#  'randomforestclassifier': RandomForestClassifier(random_state=42),
#  'columntransformer__n_jobs': None,
#  'columntransformer__remainder': 'drop',
#  'columntransformer__sparse_threshold': 0.3,
#  'columntransformer__transformer_weights': None,
#  'columntransformer__transformers': [('standardscaler',
#    StandardScaler(),
#    <sklearn.compose._column_transformer.make_column_selector at 0x1d09a00d640>),
#   ('onehotencoder',
#    OneHotEncoder(handle_unknown='ignore', sparse=False),
#    <sklearn.compose._column_transformer.make_column_selector at 0x1d098affd90>)],
#  'columntransformer__verbose': False,
#  'columntransformer__verbose_feature_names_out': True,
#  'columntransformer__standardscaler': StandardScaler(),
#  'columntransformer__onehotencoder': OneHotEncoder(handle_unknown='ignore', sparse=False),
#  'columntransformer__standardscaler__copy': True,
#  'columntransformer__standardscaler__with_mean': True,
#  'columntransformer__standardscaler__with_std': True,
#  'columntransformer__onehotencoder__categories': 'auto',
#  'columntransformer__onehotencoder__drop': None,
#  'columntransformer__onehotencoder__dtype': numpy.float64,
#  'columntransformer__onehotencoder__handle_unknown': 'ignore',
#  'columntransformer__onehotencoder__max_categories': None,
#  'columntransformer__onehotencoder__min_frequency': None,
#  'columntransformer__onehotencoder__sparse': False,
#  'randomforestclassifier__bootstrap': True,
#  'randomforestclassifier__ccp_alpha': 0.0,
#  'randomforestclassifier__class_weight': None,
#  'randomforestclassifier__criterion': 'gini',
#  'randomforestclassifier__max_depth': None,
#  'randomforestclassifier__max_features': 'sqrt',
#  'randomforestclassifier__max_leaf_nodes': None,
#  'randomforestclassifier__max_samples': None,
#  'randomforestclassifier__min_impurity_decrease': 0.0,
#  'randomforestclassifier__min_samples_leaf': 1,
#  'randomforestclassifier__min_samples_split': 2,
#  'randomforestclassifier__min_weight_fraction_leaf': 0.0,
#  'randomforestclassifier__n_estimators': 100,
#  'randomforestclassifier__n_jobs': None,
#  'randomforestclassifier__oob_score': False,
#  'randomforestclassifier__random_state': 42,
#  'randomforestclassifier__verbose': 0,
#  'randomforestclassifier__warm_start': False}

# %% [markdown]
# #### Base GS

# %%
param_grid = {
    'randomforestclassifier__max_depth': list(range(min_depth,max(est_depths)+1)),
}

# %%
model_pipe_gs = GridSearchCV(model_pipe, param_grid)

# %%
# %%time
model_pipe_gs.fit(X_train,y_train[target].values.ravel())
print(model_pipe_gs.best_params_)
# Out:
# {'randomforestclassifier__max_depth': 47}
# CPU times: total: 6min 51s
# Wall time: 6min 55s

# %%
print('Training accuracy:', model_pipe_gs.score(X_train, y_train))
print('Testing accuracy:', model_pipe_gs.score(X_test, y_test))
# Out:
# Training accuracy: 0.9670417294232303
# Testing accuracy: 0.835223245924876

# %%
classification_metrics(model_pipe_gs)
# Out:
# ------------------------------------------------------------
# [i] CLASSIFICATION REPORT FOR: Test Data
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.87      0.91      0.89      8481
#            1       0.70      0.60      0.64      2807
#
#     accuracy                           0.84     11288
#    macro avg       0.78      0.76      0.77     11288
# weighted avg       0.83      0.84      0.83     11288

# %% [markdown]
# #### Base GS 2

# %%
param_grid2 = {
    'randomforestclassifier__max_depth': list(range(min_depth,max(est_depths)+1)),
     'randomforestclassifier__n_estimators': [100, 150, 200, 250]
 }

# %%
model_pipe_gs2 = GridSearchCV(model_pipe, param_grid2, verbose=2)

# %%
# %%time
model_pipe_gs2.fit(X_train,y_train[target].values.ravel())
print(model_pipe_gs2.best_params_)
# Out:
# Fitting 5 folds for each of 104 candidates, totalling 520 fits
# [CV] END randomforestclassifier__max_depth=39, randomforestclassifier__n_estimators=100; total time=   3.3s
# [CV] END randomforestclassifier__max_depth=39, randomforestclassifier__n_estimators=100; total time=   3.1s
# [CV] END randomforestclassifier__max_depth=39, randomforestclassifier__n_estimators=100; total time=   3.0s
# [CV] END randomforestclassifier__max_depth=39, randomforestclassifier__n_estimators=100; total time=   3.0s
# [CV] END randomforestclassifier__max_depth=39, randomforestclassifier__n_estimators=100; total time=   3.0s
# [CV] END randomforestclassifier__max_depth=39, randomforestclassifier__n_estimators=150; total time=   4.7s
# [CV] END randomforestclassifier__max_depth=39, randomforestclassifier__n_estimators=150; total time=   4.5s
# [CV] END randomforestclassifier__max_depth=39, randomforestclassifier__n_estimators=150; total time=   4.5s
# [CV] END randomforestclassifier__max_depth=39, randomforestclassifier__n_estimators=150; total time=   4.7s
# [CV] END randomforestclassifier__max_depth=39, randomforestclassifier__n_estimators=150; total time=   5.4s
# [CV] END randomforestclassifier__max_depth=39, randomforestclassifier__n_estimators=200; total time=   6.3s
# [CV] END randomforestclassifier__max_depth=39, randomforestclassifier__n_estimators=200; total time=   6.0s
# [CV] END randomforestclassifier__max_depth=39, randomforestclassifier__n_estimators=200; total time=   6.1s
# [CV] END randomforestclassifier__max_depth=39, randomforestclassifier__n_estimators=200; total time=   6.1s
# [CV] END randomforestclassifier__max_depth=39, randomforestclassifier__n_estimators=200; total time=   8.6s
# [CV] END randomforestclassifier__max_depth=39, randomforestclassifier__n_estimators=250; total time=   8.9s
# [CV] END randomforestclassifier__max_depth=39, randomforestclassifier__n_estimators=250; total time=   8.0s
# [CV] END randomforestclassifier__max_depth=39, randomforestclassifier__n_estimators=250; total time=   8.4s
# [CV] END randomforestclassifier__max_depth=39, randomforestclassifier__n_estimators=250; total time=   8.8s
# [CV] END randomforestclassifier__max_depth=39, randomforestclassifier__n_estimators=250; total time=   8.6s
# [CV] END randomforestclassifier__max_depth=40, randomforestclassifier__n_estimators=100; total time=   3.5s
# [CV] END randomforestclassifier__max_depth=40, randomforestclassifier__n_estimators=100; total time=   3.0s
# [CV] END randomforestclassifier__max_depth=40, randomforestclassifier__n_estimators=100; total time=   3.0s
# [CV] END randomforestclassifier__max_depth=40, randomforestclassifier__n_estimators=100; total time=   3.1s
# [CV] END randomforestclassifier__max_depth=40, randomforestclassifier__n_estimators=100; total time=   3.0s
# [CV] END randomforestclassifier__max_depth=40, randomforestclassifier__n_estimators=150; total time=   4.6s
# [CV] END randomforestclassifier__max_depth=40, randomforestclassifier__n_estimators=150; total time=   4.5s
# [CV] END randomforestclassifier__max_depth=40, randomforestclassifier__n_estimators=150; total time=   4.5s
# [CV] END randomforestclassifier__max_depth=40, randomforestclassifier__n_estimators=150; total time=   4.6s
# [CV] END randomforestclassifier__max_depth=40, randomforestclassifier__n_estimators=150; total time=   4.5s
# [CV] END randomforestclassifier__max_depth=40, randomforestclassifier__n_estimators=200; total time=   6.3s
# [CV] END randomforestclassifier__max_depth=40, randomforestclassifier__n_estimators=200; total time=   6.7s
# [CV] END randomforestclassifier__max_depth=40, randomforestclassifier__n_estimators=200; total time=   6.2s
# [CV] END randomforestclassifier__max_depth=40, randomforestclassifier__n_estimators=200; total time=   6.4s
# [CV] END randomforestclassifier__max_depth=40, randomforestclassifier__n_estimators=200; total time=   6.1s
# [CV] END randomforestclassifier__max_depth=40, randomforestclassifier__n_estimators=250; total time=   7.7s
# [CV] END randomforestclassifier__max_depth=40, randomforestclassifier__n_estimators=250; total time=   7.5s
# [CV] END randomforestclassifier__max_depth=40, randomforestclassifier__n_estimators=250; total time=   7.7s
# [CV] END randomforestclassifier__max_depth=40, randomforestclassifier__n_estimators=250; total time=   8.6s
# [CV] END randomforestclassifier__max_depth=40, randomforestclassifier__n_estimators=250; total time=   7.6s
# [CV] END randomforestclassifier__max_depth=41, randomforestclassifier__n_estimators=100; total time=   3.1s
# [CV] END randomforestclassifier__max_depth=41, randomforestclassifier__n_estimators=100; total time=   3.1s
# [CV] END randomforestclassifier__max_depth=41, randomforestclassifier__n_estimators=100; total time=   3.0s
# [CV] END randomforestclassifier__max_depth=41, randomforestclassifier__n_estimators=100; total time=   3.1s
# [CV] END randomforestclassifier__max_depth=41, randomforestclassifier__n_estimators=100; total time=   3.2s
# [CV] END randomforestclassifier__max_depth=41, randomforestclassifier__n_estimators=150; total time=   4.7s
# [CV] END randomforestclassifier__max_depth=41, randomforestclassifier__n_estimators=150; total time=   5.0s
# [CV] END randomforestclassifier__max_depth=41, randomforestclassifier__n_estimators=150; total time=   4.7s
# [CV] END randomforestclassifier__max_depth=41, randomforestclassifier__n_estimators=150; total time=   4.7s
# [CV] END randomforestclassifier__max_depth=41, randomforestclassifier__n_estimators=150; total time=   4.5s
# [CV] END randomforestclassifier__max_depth=41, randomforestclassifier__n_estimators=200; total time=   7.2s
# [CV] END randomforestclassifier__max_depth=41, randomforestclassifier__n_estimators=200; total time=   6.3s
# [CV] END randomforestclassifier__max_depth=41, randomforestclassifier__n_estimators=200; total time=   6.1s
# [CV] END randomforestclassifier__max_depth=41, randomforestclassifier__n_estimators=200; total time=   6.1s
# [CV] END randomforestclassifier__max_depth=41, randomforestclassifier__n_estimators=200; total time=   6.1s
# [CV] END randomforestclassifier__max_depth=41, randomforestclassifier__n_estimators=250; total time=   9.7s
# [CV] END randomforestclassifier__max_depth=41, randomforestclassifier__n_estimators=250; total time=  12.6s
# [CV] END randomforestclassifier__max_depth=41, randomforestclassifier__n_estimators=250; total time=   9.2s
# [CV] END randomforestclassifier__max_depth=41, randomforestclassifier__n_estimators=250; total time=   7.7s
# [CV] END randomforestclassifier__max_depth=41, randomforestclassifier__n_estimators=250; total time=   7.6s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=100; total time=   3.1s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=100; total time=   3.0s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=100; total time=   3.0s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=100; total time=   3.1s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=100; total time=   3.0s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=150; total time=   4.6s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=150; total time=   4.6s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=150; total time=   4.5s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=150; total time=   4.6s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=150; total time=   4.7s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=200; total time=   6.1s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=200; total time=   6.2s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=200; total time=   6.1s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=200; total time=   6.2s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=200; total time=   6.2s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=250; total time=   7.8s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=250; total time=   7.8s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=250; total time=   7.7s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=250; total time=   7.8s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=250; total time=   7.8s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=100; total time=   3.2s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=100; total time=   3.1s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=100; total time=   3.1s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=100; total time=   3.1s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=100; total time=   3.1s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=150; total time=   4.8s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=150; total time=   4.6s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=150; total time=   4.7s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=150; total time=   4.7s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=150; total time=   4.6s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=200; total time=   6.2s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=200; total time=   8.6s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=200; total time=   7.1s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=200; total time=   7.3s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=200; total time=   7.5s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=250; total time=  14.6s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=250; total time=   9.0s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=250; total time=   8.5s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=250; total time=   8.6s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=250; total time=   7.9s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=100; total time=   3.1s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=100; total time=   3.1s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=100; total time=   3.1s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=100; total time=   3.1s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=100; total time=   3.4s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=150; total time=   4.7s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=150; total time=   4.6s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=150; total time=   4.7s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=150; total time=   4.8s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=150; total time=   4.6s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=200; total time=   6.3s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=200; total time=   6.2s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=200; total time=   6.2s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=200; total time=   6.2s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=200; total time=   6.1s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=250; total time=   7.9s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=250; total time=   7.7s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=250; total time=   7.6s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=250; total time=   7.7s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=250; total time=   7.7s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=100; total time=   3.2s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=100; total time=   3.1s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=100; total time=   3.1s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=100; total time=   3.1s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=100; total time=   3.1s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=150; total time=   4.7s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=150; total time=   4.7s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=150; total time=   4.6s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=150; total time=   4.7s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=150; total time=   4.6s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=200; total time=   6.2s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=200; total time=   6.2s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=200; total time=   6.2s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=200; total time=   6.2s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=200; total time=   6.2s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=250; total time=   7.8s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=250; total time=   7.7s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=250; total time=   7.7s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=250; total time=   7.8s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=250; total time=   7.7s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=100; total time=   3.1s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=100; total time=   3.1s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=100; total time=   3.1s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=100; total time=   3.3s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=100; total time=   3.2s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=150; total time=   4.7s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=150; total time=   4.6s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=150; total time=   4.6s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=150; total time=   4.8s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=150; total time=   4.6s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=200; total time=   6.3s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=200; total time=   6.2s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=200; total time=   6.1s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=200; total time=   6.2s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=200; total time=   6.1s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=250; total time=   8.0s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=250; total time=   7.7s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=250; total time=   7.8s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=250; total time=   7.8s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=250; total time=   7.8s
# [CV] END randomforestclassifier__max_depth=47, randomforestclassifier__n_estimators=100; total time=   3.3s
# [CV] END randomforestclassifier__max_depth=47, randomforestclassifier__n_estimators=100; total time=   3.1s
# [CV] END randomforestclassifier__max_depth=47, randomforestclassifier__n_estimators=100; total time=   3.1s
# [CV] END randomforestclassifier__max_depth=47, randomforestclassifier__n_estimators=100; total time=   3.1s
# [CV] END randomforestclassifier__max_depth=47, randomforestclassifier__n_estimators=100; total time=   3.1s
# [CV] END randomforestclassifier__max_depth=47, randomforestclassifier__n_estimators=150; total time=   4.8s
# [CV] END randomforestclassifier__max_depth=47, randomforestclassifier__n_estimators=150; total time=   4.6s
# [CV] END randomforestclassifier__max_depth=47, randomforestclassifier__n_estimators=150; total time=   4.6s
# [CV] END randomforestclassifier__max_depth=47, randomforestclassifier__n_estimators=150; total time=   4.7s
# [CV] END randomforestclassifier__max_depth=47, randomforestclassifier__n_estimators=150; total time=   4.6s
# [CV] END randomforestclassifier__max_depth=47, randomforestclassifier__n_estimators=200; total time=   6.4s
# [CV] END randomforestclassifier__max_depth=47, randomforestclassifier__n_estimators=200; total time=   6.2s
# [CV] END randomforestclassifier__max_depth=47, randomforestclassifier__n_estimators=200; total time=   6.2s
# [CV] END randomforestclassifier__max_depth=47, randomforestclassifier__n_estimators=200; total time=   6.2s
# [CV] END randomforestclassifier__max_depth=47, randomforestclassifier__n_estimators=200; total time=   6.2s
# [CV] END randomforestclassifier__max_depth=47, randomforestclassifier__n_estimators=250; total time=   7.9s
# [CV] END randomforestclassifier__max_depth=47, randomforestclassifier__n_estimators=250; total time=   7.7s
# [CV] END randomforestclassifier__max_depth=47, randomforestclassifier__n_estimators=250; total time=   7.7s
# [CV] END randomforestclassifier__max_depth=47, randomforestclassifier__n_estimators=250; total time=   7.9s
# [CV] END randomforestclassifier__max_depth=47, randomforestclassifier__n_estimators=250; total time=   7.8s
# [CV] END randomforestclassifier__max_depth=48, randomforestclassifier__n_estimators=100; total time=   3.2s
# [CV] END randomforestclassifier__max_depth=48, randomforestclassifier__n_estimators=100; total time=   3.1s
# [CV] END randomforestclassifier__max_depth=48, randomforestclassifier__n_estimators=100; total time=   3.1s
# [CV] END randomforestclassifier__max_depth=48, randomforestclassifier__n_estimators=100; total time=   3.1s
# [CV] END randomforestclassifier__max_depth=48, randomforestclassifier__n_estimators=100; total time=   3.1s
# [CV] END randomforestclassifier__max_depth=48, randomforestclassifier__n_estimators=150; total time=   4.7s
# [CV] END randomforestclassifier__max_depth=48, randomforestclassifier__n_estimators=150; total time=   4.6s
# [CV] END randomforestclassifier__max_depth=48, randomforestclassifier__n_estimators=150; total time=   4.8s
# [CV] END randomforestclassifier__max_depth=48, randomforestclassifier__n_estimators=150; total time=   4.7s
# [CV] END randomforestclassifier__max_depth=48, randomforestclassifier__n_estimators=150; total time=   4.6s
# [CV] END randomforestclassifier__max_depth=48, randomforestclassifier__n_estimators=200; total time=   6.3s
# [CV] END randomforestclassifier__max_depth=48, randomforestclassifier__n_estimators=200; total time=   6.4s
# [CV] END randomforestclassifier__max_depth=48, randomforestclassifier__n_estimators=200; total time=   6.1s
# [CV] END randomforestclassifier__max_depth=48, randomforestclassifier__n_estimators=200; total time=   6.3s
# [CV] END randomforestclassifier__max_depth=48, randomforestclassifier__n_estimators=200; total time=   6.2s
# [CV] END randomforestclassifier__max_depth=48, randomforestclassifier__n_estimators=250; total time=   7.9s
# [CV] END randomforestclassifier__max_depth=48, randomforestclassifier__n_estimators=250; total time=   7.8s
# [CV] END randomforestclassifier__max_depth=48, randomforestclassifier__n_estimators=250; total time=   8.6s
# [CV] END randomforestclassifier__max_depth=48, randomforestclassifier__n_estimators=250; total time=   7.8s
# [CV] END randomforestclassifier__max_depth=48, randomforestclassifier__n_estimators=250; total time=   7.9s
# [CV] END randomforestclassifier__max_depth=49, randomforestclassifier__n_estimators=100; total time=   3.2s
# [CV] END randomforestclassifier__max_depth=49, randomforestclassifier__n_estimators=100; total time=   3.3s
# [CV] END randomforestclassifier__max_depth=49, randomforestclassifier__n_estimators=100; total time=   3.2s
# [CV] END randomforestclassifier__max_depth=49, randomforestclassifier__n_estimators=100; total time=   3.1s
# [CV] END randomforestclassifier__max_depth=49, randomforestclassifier__n_estimators=100; total time=   3.2s
# [CV] END randomforestclassifier__max_depth=49, randomforestclassifier__n_estimators=150; total time=   4.7s
# [CV] END randomforestclassifier__max_depth=49, randomforestclassifier__n_estimators=150; total time=   4.7s
# [CV] END randomforestclassifier__max_depth=49, randomforestclassifier__n_estimators=150; total time=   4.7s
# [CV] END randomforestclassifier__max_depth=49, randomforestclassifier__n_estimators=150; total time=   4.7s
# [CV] END randomforestclassifier__max_depth=49, randomforestclassifier__n_estimators=150; total time=   5.2s
# [CV] END randomforestclassifier__max_depth=49, randomforestclassifier__n_estimators=200; total time=   6.4s
# [CV] END randomforestclassifier__max_depth=49, randomforestclassifier__n_estimators=200; total time=   6.2s
# [CV] END randomforestclassifier__max_depth=49, randomforestclassifier__n_estimators=200; total time=   6.3s
# [CV] END randomforestclassifier__max_depth=49, randomforestclassifier__n_estimators=200; total time=   6.3s
# [CV] END randomforestclassifier__max_depth=49, randomforestclassifier__n_estimators=200; total time=   6.8s
# [CV] END randomforestclassifier__max_depth=49, randomforestclassifier__n_estimators=250; total time=   9.3s
# [CV] END randomforestclassifier__max_depth=49, randomforestclassifier__n_estimators=250; total time=   8.8s
# [CV] END randomforestclassifier__max_depth=49, randomforestclassifier__n_estimators=250; total time=   8.3s
# [CV] END randomforestclassifier__max_depth=49, randomforestclassifier__n_estimators=250; total time=   8.3s
# [CV] END randomforestclassifier__max_depth=49, randomforestclassifier__n_estimators=250; total time=   8.2s
# [CV] END randomforestclassifier__max_depth=50, randomforestclassifier__n_estimators=100; total time=   3.2s
# [CV] END randomforestclassifier__max_depth=50, randomforestclassifier__n_estimators=100; total time=   4.2s
# [CV] END randomforestclassifier__max_depth=50, randomforestclassifier__n_estimators=100; total time=   3.1s
# [CV] END randomforestclassifier__max_depth=50, randomforestclassifier__n_estimators=100; total time=   3.2s
# [CV] END randomforestclassifier__max_depth=50, randomforestclassifier__n_estimators=100; total time=   3.6s
# [CV] END randomforestclassifier__max_depth=50, randomforestclassifier__n_estimators=150; total time=   4.7s
# [CV] END randomforestclassifier__max_depth=50, randomforestclassifier__n_estimators=150; total time=   5.4s
# [CV] END randomforestclassifier__max_depth=50, randomforestclassifier__n_estimators=150; total time=   5.5s
# [CV] END randomforestclassifier__max_depth=50, randomforestclassifier__n_estimators=150; total time=   5.6s
# [CV] END randomforestclassifier__max_depth=50, randomforestclassifier__n_estimators=150; total time=   5.5s
# [CV] END randomforestclassifier__max_depth=50, randomforestclassifier__n_estimators=200; total time=   7.1s
# [CV] END randomforestclassifier__max_depth=50, randomforestclassifier__n_estimators=200; total time=   6.3s
# [CV] END randomforestclassifier__max_depth=50, randomforestclassifier__n_estimators=200; total time=   6.3s
# [CV] END randomforestclassifier__max_depth=50, randomforestclassifier__n_estimators=200; total time=   6.7s
# [CV] END randomforestclassifier__max_depth=50, randomforestclassifier__n_estimators=200; total time=   6.2s
# [CV] END randomforestclassifier__max_depth=50, randomforestclassifier__n_estimators=250; total time=   7.9s
# [CV] END randomforestclassifier__max_depth=50, randomforestclassifier__n_estimators=250; total time=   7.9s
# [CV] END randomforestclassifier__max_depth=50, randomforestclassifier__n_estimators=250; total time=   7.7s
# [CV] END randomforestclassifier__max_depth=50, randomforestclassifier__n_estimators=250; total time=   8.0s
# [CV] END randomforestclassifier__max_depth=50, randomforestclassifier__n_estimators=250; total time=   7.9s
# [CV] END randomforestclassifier__max_depth=51, randomforestclassifier__n_estimators=100; total time=   3.2s
# [CV] END randomforestclassifier__max_depth=51, randomforestclassifier__n_estimators=100; total time=   3.1s
# [CV] END randomforestclassifier__max_depth=51, randomforestclassifier__n_estimators=100; total time=   3.0s
# [CV] END randomforestclassifier__max_depth=51, randomforestclassifier__n_estimators=100; total time=   3.1s
# [CV] END randomforestclassifier__max_depth=51, randomforestclassifier__n_estimators=100; total time=   3.1s
# [CV] END randomforestclassifier__max_depth=51, randomforestclassifier__n_estimators=150; total time=   5.3s
# [CV] END randomforestclassifier__max_depth=51, randomforestclassifier__n_estimators=150; total time=   4.7s
# [CV] END randomforestclassifier__max_depth=51, randomforestclassifier__n_estimators=150; total time=   4.6s
# [CV] END randomforestclassifier__max_depth=51, randomforestclassifier__n_estimators=150; total time=   4.7s
# [CV] END randomforestclassifier__max_depth=51, randomforestclassifier__n_estimators=150; total time=   4.7s
# [CV] END randomforestclassifier__max_depth
randomforestclassifier__n_estimators=250; total time=   7.7s
# [CV] END randomforestclassifier__max_depth=64, randomforestclassifier__n_estimators=250; total time=   7.7s
# [CV] END randomforestclassifier__max_depth=64, randomforestclassifier__n_estimators=250; total time=   7.8s
# [CV] END randomforestclassifier__max_depth=64, randomforestclassifier__n_estimators=250; total time=   7.7s
# {'randomforestclassifier__max_depth': 39, 'randomforestclassifier__n_estimators': 200}
# CPU times: total: 47min 58s
# Wall time: 48min 55s

# %%
print('Training accuracy:', model_pipe_gs2.score(X_train, y_train))
print('Testing accuracy:', model_pipe_gs2.score(X_test, y_test))
classification_metrics(model_pipe_gs2)
# Out:
# Training accuracy: 0.9668645344201293
# Testing accuracy: 0.8372608079376329
# ------------------------------------------------------------
# [i] CLASSIFICATION REPORT FOR: Test Data
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.87      0.92      0.89      8481
#            1       0.70      0.59      0.65      2807
#
#     accuracy                           0.84     11288
#    macro avg       0.79      0.76      0.77     11288
# weighted avg       0.83      0.84      0.83     11288

# %% [markdown]
# #### Base PCA 95%

# %%
model_pipe_pca = make_pipeline(cols_transformer,pca95,model)

# %%
# %%time
model_pipe_pca.fit(X_train,y_train[target].values.ravel())
# Out:
# CPU times: total: 14.1 s
# Wall time: 13.5 s
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('standardscaler',
#                                                   StandardScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000001D09A00D640>),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000001D098AFFD90>)])),
#                 ('pca', PCA(n_components=0.95)),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(random_state=42))])

# %%
print('Training accuracy:', model_pipe_pca.score(X_train, y_train))
print('Testing accuracy:',  model_pipe_pca.score(X_test, y_test))
classification_metrics(model_pipe_pca)
# Out:
# Training accuracy: 0.967071261923747
# Testing accuracy: 0.8233522324592487
# ------------------------------------------------------------
# [i] CLASSIFICATION REPORT FOR: Test Data
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.87      0.91      0.89      8481
#            1       0.67      0.58      0.62      2807
#
#     accuracy                           0.82     11288
#    macro avg       0.77      0.74      0.75     11288
# weighted avg       0.82      0.82      0.82     11288

# %% [markdown]
# #### PCA GS

# %%
est_depths = [estimator.get_depth() for estimator in model_pipe_pca.named_steps['randomforestclassifier'].estimators_]
print(f'The max depth of pca Random Forest Classifier is {max(est_depths)}')

n_estimators = model_pipe_pca.named_steps['randomforestclassifier'].n_estimators

print("Number of Estimators: ", n_estimators)

min_depth = np.min(est_depths)
mean_depth = np.mean(est_depths)
median_depth = np.median(est_depths)
mode_depth = np.argmax(np.bincount(est_depths))

print("Mean Depth: ", mean_depth)
print("Median Depth: ", median_depth)
print("Mode Depth: ", mode_depth)
print("Min Depth: ", min_depth)
# Out:
# The max depth of pca Random Forest Classifier is 46
# Number of Estimators:  100
# Mean Depth:  36.82
# Median Depth:  37.0
# Mode Depth:  38
# Min Depth:  30

# %%
param_grid = {
    'randomforestclassifier__max_depth': list(range(min_depth,max(est_depths)+1)),
}

# %%
model_pipe_pca_gs = GridSearchCV(model_pipe_pca, param_grid, verbose=2)

# %%
# %%time
model_pipe_pca_gs.fit(X_train,y_train[target].values.ravel())
print(model_pipe_pca_gs.best_params_)
# Out:
# Fitting 5 folds for each of 17 candidates, totalling 85 fits
# [CV] END ...............randomforestclassifier__max_depth=30; total time=  10.4s
# [CV] END ...............randomforestclassifier__max_depth
total time=  10.4s
# [CV] END ...............randomforestclassifier__max_depth=43; total time=  10.9s
# [CV] END ...............randomforestclassifier__max_depth=43; total time=  10.2s
# [CV] END ...............randomforestclassifier__max_depth=44; total time=  10.3s
# [CV] END ...............randomforestclassifier__max_depth=44; total time=  10.4s
# [CV] END ...............randomforestclassifier__max_depth=44; total time=  10.4s
# [CV] END ...............randomforestclassifier__max_depth=44; total time=  10.5s
# [CV] END ...............randomforestclassifier__max_depth=44; total time=  10.3s
# [CV] END ...............randomforestclassifier__max_depth=45; total time=  10.3s
# [CV] END ...............randomforestclassifier__max_depth=45; total time=  10.5s
# [CV] END ...............randomforestclassifier__max_depth=45; total time=  10.8s
# [CV] END ...............randomforestclassifier__max_depth=45; total time=  10.5s
# [CV] END ...............randomforestclassifier__max_depth=45; total time=  10.2s
# [CV] END ...............randomforestclassifier__max_depth=46; total time=  10.2s
# [CV] END ...............randomforestclassifier__max_depth=46; total time=  10.4s
# [CV] END ...............randomforestclassifier__max_depth=46; total time=  10.4s
# [CV] END ...............randomforestclassifier__max_depth=46; total time=  10.5s
# [CV] END ...............randomforestclassifier__max_depth=46; total time=  10.2s
# {'randomforestclassifier__max_depth': 31}
# CPU times: total: 16min 39s
# Wall time: 15min 8s

# %%
print('Training accuracy:', model_pipe_pca_gs.score(X_train, y_train))
print('Testing accuracy:',  model_pipe_pca_gs.score(X_test, y_test))
classification_metrics(model_pipe_pca_gs)
# Out:
# Training accuracy: 0.967071261923747
# Testing accuracy: 0.8234408221119773
# ------------------------------------------------------------
# [i] CLASSIFICATION REPORT FOR: Test Data
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.86      0.91      0.89      8481
#            1       0.67      0.57      0.62      2807
#
#     accuracy                           0.82     11288
#    macro avg       0.77      0.74      0.75     11288
# weighted avg       0.82      0.82      0.82     11288

# %% [markdown]
# #### PCA GS 2

# %%
param_grid2 = {
    'randomforestclassifier__max_depth': list(range(min_depth,max(est_depths)+1)),
     'randomforestclassifier__n_estimators': [100, 150, 200, 250]
 }

# %%
model_pipe_pca_gs2 = GridSearchCV(model_pipe_pca, param_grid2, verbose=2)

# %%
# %%time
model_pipe_pca_gs2.fit(X_train, y_train[target].values.ravel())
print(model_pipe_pca_gs2.best_params_)
# Out:
# Fitting 5 folds for each of 68 candidates, totalling 340 fits
# [CV] END randomforestclassifier__max_depth=30, randomforestclassifier__n_estimators=100; total time=  10.5s
# [CV] END randomforestclassifier__max_depth=30, randomforestclassifier__n_estimators=100; total time=  10.4s
# [CV] END randomforestclassifier__max_depth=30, randomforestclassifier__n_estimators=100; total time=  11.0s
# [CV] END randomforestclassifier__max_depth=30, randomforestclassifier__n_estimators=100; total time=  10.7s
# [CV] END randomforestclassifier__max_depth=30, randomforestclassifier__n_estimators=100; total time=  10.3s
# [CV] END randomforestclassifier__max_depth=30, randomforestclassifier__n_estimators=150; total time=  15.4s
# [CV] END randomforestclassifier__max_depth=30, randomforestclassifier__n_estimators=150; total time=  15.5s
# [CV] END randomforestclassifier__max_depth=30, randomforestclassifier__n_estimators=150; total time=  15.4s
# [CV] END randomforestclassifier__max_depth=30, randomforestclassifier__n_estimators=150; total time=  15.6s
# [CV] END randomforestclassifier__max_depth=30, randomforestclassifier__n_estimators=150; total time=  15.4s
# [CV] END randomforestclassifier__max_depth=30, randomforestclassifier__n_estimators=200; total time=  20.6s
# [CV] END randomforestclassifier__max_depth=30, randomforestclassifier__n_estimators=200; total time=  21.0s
# [CV] END randomforestclassifier__max_depth=30, randomforestclassifier__n_estimators=200; total time=  20.7s
# [CV] END randomforestclassifier__max_depth=30, randomforestclassifier__n_estimators=200; total time=  20.9s
# [CV] END randomforestclassifier__max_depth=30, randomforestclassifier__n_estimators=200; total time=  20.7s
# [CV] END randomforestclassifier__max_depth=30, randomforestclassifier__n_estimators=250; total time=  25.5s
# [CV] END randomforestclassifier__max_depth=30, randomforestclassifier__n_estimators=250; total time=  26.2s
# [CV] END randomforestclassifier__max_depth=30, randomforestclassifier__n_estimators=250; total time=  25.6s
# [CV] END randomforestclassifier__max_depth=30, randomforestclassifier__n_estimators=250; total time=  26.2s
# [CV] END randomforestclassifier__max_depth=30, randomforestclassifier__n_estimators=250; total time=  25.7s
# [CV] END randomforestclassifier__max_depth=31, randomforestclassifier__n_estimators=100; total time=  10.2s
# [CV] END randomforestclassifier__max_depth=31, randomforestclassifier__n_estimators=100; total time=  10.3s
# [CV] END randomforestclassifier__max_depth=31, randomforestclassifier__n_estimators=100; total time=  10.4s
# [CV] END randomforestclassifier__max_depth=31, randomforestclassifier__n_estimators=100; total time=  10.4s
# [CV] END randomforestclassifier__max_depth=31, randomforestclassifier__n_estimators=100; total time=  10.2s
# [CV] END randomforestclassifier__max_depth=31, randomforestclassifier__n_estimators=150; total time=  15.4s
# [CV] END randomforestclassifier__max_depth=31, randomforestclassifier__n_estimators=150; total time=  15.5s
# [CV] END randomforestclassifier__max_depth=31, randomforestclassifier__n_estimators=150; total time=  15.3s
# [CV] END randomforestclassifier__max_depth=31, randomforestclassifier__n_estimators=150; total time=  15.6s
# [CV] END randomforestclassifier__max_depth=31, randomforestclassifier__n_estimators=150; total time=  15.6s
# [CV] END randomforestclassifier__max_depth=31, randomforestclassifier__n_estimators=200; total time=  20.5s
# [CV] END randomforestclassifier__max_depth=31, randomforestclassifier__n_estimators=200; total time=  20.8s
# [CV] END randomforestclassifier__max_depth=31, randomforestclassifier__n_estimators=200; total time=  20.5s
# [CV] END randomforestclassifier__max_depth=31, randomforestclassifier__n_estimators=200; total time=  21.0s
# [CV] END randomforestclassifier__max_depth=31, randomforestclassifier__n_estimators=200; total time=  20.6s
# [CV] END randomforestclassifier__max_depth=31, randomforestclassifier__n_estimators=250; total time=  25.7s
# [CV] END randomforestclassifier__max_depth=31, randomforestclassifier__n_estimators=250; total time=  26.2s
# [CV] END randomforestclassifier__max_depth=31, randomforestclassifier__n_estimators=250; total time=  25.6s
# [CV] END randomforestclassifier__max_depth=31, randomforestclassifier__n_estimators=250; total time=  26.2s
# [CV] END randomforestclassifier__max_depth=31, randomforestclassifier__n_estimators=250; total time=  25.6s
# [CV] END randomforestclassifier__max_depth=32, randomforestclassifier__n_estimators=100; total time=  10.3s
# [CV] END randomforestclassifier__max_depth=32, randomforestclassifier__n_estimators=100; total time=  10.5s
# [CV] END randomforestclassifier__max_depth=32, randomforestclassifier__n_estimators=100; total time=  10.3s
# [CV] END randomforestclassifier__max_depth=32, randomforestclassifier__n_estimators=100; total time=  10.5s
# [CV] END randomforestclassifier__max_depth=32, randomforestclassifier__n_estimators=100; total time=  10.3s
# [CV] END randomforestclassifier__max_depth=32, randomforestclassifier__n_estimators=150; total time=  15.5s
# [CV] END randomforestclassifier__max_depth=32, randomforestclassifier__n_estimators=150; total time=  15.6s
# [CV] END randomforestclassifier__max_depth=32, randomforestclassifier__n_estimators=150; total time=  15.4s
# [CV] END randomforestclassifier__max_depth=32, randomforestclassifier__n_estimators=150; total time=  15.8s
# [CV] END randomforestclassifier__max_depth=32, randomforestclassifier__n_estimators=150; total time=  15.5s
# [CV] END randomforestclassifier__max_depth=32, randomforestclassifier__n_estimators=200; total time=  20.5s
# [CV] END randomforestclassifier__max_depth=32, randomforestclassifier__n_estimators=200; total time=  20.9s
# [CV] END randomforestclassifier__max_depth=32, randomforestclassifier__n_estimators=200; total time=  20.5s
# [CV] END randomforestclassifier__max_depth=32, randomforestclassifier__n_estimators=200; total time=  21.0s
# [CV] END randomforestclassifier__max_depth=32, randomforestclassifier__n_estimators=200; total time=  20.7s
# [CV] END randomforestclassifier__max_depth=32, randomforestclassifier__n_estimators=250; total time=  25.7s
# [CV] END randomforestclassifier__max_depth=32, randomforestclassifier__n_estimators=250; total time=  26.0s
# [CV] END randomforestclassifier__max_depth=32, randomforestclassifier__n_estimators=250; total time=  25.6s
# [CV] END randomforestclassifier__max_depth=32, randomforestclassifier__n_estimators=250; total time=  26.1s
# [CV] END randomforestclassifier__max_depth=32, randomforestclassifier__n_estimators=250; total time=  25.8s
# [CV] END randomforestclassifier__max_depth=33, randomforestclassifier__n_estimators=100; total time=  10.9s
# [CV] END randomforestclassifier__max_depth=33, randomforestclassifier__n_estimators=100; total time=  10.5s
# [CV] END randomforestclassifier__max_depth=33, randomforestclassifier__n_estimators=100; total time=  10.5s
# [CV] END randomforestclassifier__max_depth=33, randomforestclassifier__n_estimators=100; total time=  10.5s
# [CV] END randomforestclassifier__max_depth=33, randomforestclassifier__n_estimators=100; total time=  10.2s
# [CV] END randomforestclassifier__max_depth=33, randomforestclassifier__n_estimators=150; total time=  15.4s
# [CV] END randomforestclassifier__max_depth=33, randomforestclassifier__n_estimators=150; total time=  15.6s
# [CV] END randomforestclassifier__max_depth=33, randomforestclassifier__n_estimators=150; total time=  15.5s
# [CV] END randomforestclassifier__max_depth=33, randomforestclassifier__n_estimators=150; total time=  15.8s
# [CV] END randomforestclassifier__max_depth=33, randomforestclassifier__n_estimators=150; total time=  15.4s
# [CV] END randomforestclassifier__max_depth=33, randomforestclassifier__n_estimators=200; total time=  21.0s
# [CV] END randomforestclassifier__max_depth=33, randomforestclassifier__n_estimators=200; total time=  20.8s
# [CV] END randomforestclassifier__max_depth=33, randomforestclassifier__n_estimators=200; total time=  20.6s
# [CV] END randomforestclassifier__max_depth=33, randomforestclassifier__n_estimators=200; total time=  21.0s
# [CV] END randomforestclassifier__max_depth=33, randomforestclassifier__n_estimators=200; total time=  20.5s
# [CV] END randomforestclassifier__max_depth=33, randomforestclassifier__n_estimators=250; total time=  25.7s
# [CV] END randomforestclassifier__max_depth=33, randomforestclassifier__n_estimators=250; total time=  25.9s
# [CV] END randomforestclassifier__max_depth=33, randomforestclassifier__n_estimators=250; total time=  25.8s
# [CV] END randomforestclassifier__max_depth=33, randomforestclassifier__n_estimators=250; total time=  26.1s
# [CV] END randomforestclassifier__max_depth=33, randomforestclassifier__n_estimators=250; total time=  25.6s
# [CV] END randomforestclassifier__max_depth=34, randomforestclassifier__n_estimators=100; total time=  10.3s
# [CV] END randomforestclassifier__max_depth=34, randomforestclassifier__n_estimators=100; total time=  10.4s
# [CV] END randomforestclassifier__max_depth=34, randomforestclassifier__n_estimators=100; total time=  10.4s
# [CV] END randomforestclassifier__max_depth=34, randomforestclassifier__n_estimators=100; total time=  10.4s
# [CV] END randomforestclassifier__max_depth=34, randomforestclassifier__n_estimators=100; total time=  10.2s
# [CV] END randomforestclassifier__max_depth=34, randomforestclassifier__n_estimators=150; total time=  15.4s
# [CV] END randomforestclassifier__max_depth=34, randomforestclassifier__n_estimators=150; total time=  15.5s
# [CV] END randomforestclassifier__max_depth=34, randomforestclassifier__n_estimators=150; total time=  15.5s
# [CV] END randomforestclassifier__max_depth=34, randomforestclassifier__n_estimators=150; total time=  15.6s
# [CV] END randomforestclassifier__max_depth=34, randomforestclassifier__n_estimators=150; total time=  15.3s
# [CV] END randomforestclassifier__max_depth=34, randomforestclassifier__n_estimators=200; total time=  20.5s
# [CV] END randomforestclassifier__max_depth=34, randomforestclassifier__n_estimators=200; total time=  20.7s
# [CV] END randomforestclassifier__max_depth=34, randomforestclassifier__n_estimators=200; total time=  20.6s
# [CV] END randomforestclassifier__max_depth=34, randomforestclassifier__n_estimators=200; total time=  20.7s
# [CV] END randomforestclassifier__max_depth=34, randomforestclassifier__n_estimators=200; total time=  20.9s
# [CV] END randomforestclassifier__max_depth=34, randomforestclassifier__n_estimators=250; total time=  25.7s
# [CV] END randomforestclassifier__max_depth=34, randomforestclassifier__n_estimators=250; total time=  26.0s
# [CV] END randomforestclassifier__max_depth=34, randomforestclassifier__n_estimators=250; total time=  25.7s
# [CV] END randomforestclassifier__max_depth=34, randomforestclassifier__n_estimators=250; total time=  26.0s
# [CV] END randomforestclassifier__max_depth=34, randomforestclassifier__n_estimators=250; total time=  25.7s
# [CV] END randomforestclassifier__max_depth=35, randomforestclassifier__n_estimators=100; total time=  10.2s
# [CV] END randomforestclassifier__max_depth=35, randomforestclassifier__n_estimators=100; total time=  10.4s
# [CV] END randomforestclassifier__max_depth=35, randomforestclassifier__n_estimators=100; total time=  10.4s
# [CV] END randomforestclassifier__max_depth=35, randomforestclassifier__n_estimators=100; total time=  10.4s
# [CV] END randomforestclassifier__max_depth=35, randomforestclassifier__n_estimators=100; total time=  10.2s
# [CV] END randomforestclassifier__max_depth=35, randomforestclassifier__n_estimators=150; total time=  15.5s
# [CV] END randomforestclassifier__max_depth=35, randomforestclassifier__n_estimators=150; total time=  15.5s
# [CV] END randomforestclassifier__max_depth=35, randomforestclassifier__n_estimators=150; total time=  15.6s
# [CV] END randomforestclassifier__max_depth=35, randomforestclassifier__n_estimators=150; total time=  15.7s
# [CV] END randomforestclassifier__max_depth=35, randomforestclassifier__n_estimators=150; total time=  15.3s
# [CV] END randomforestclassifier__max_depth=35, randomforestclassifier__n_estimators=200; total time=  20.5s
# [CV] END randomforestclassifier__max_depth=35, randomforestclassifier__n_estimators=200; total time=  20.8s
# [CV] END randomforestclassifier__max_depth=35, randomforestclassifier__n_estimators=200; total time=  20.6s
# [CV] END randomforestclassifier__max_depth=35, randomforestclassifier__n_estimators=200; total time=  20.9s
# [CV] END randomforestclassifier__max_depth=35, randomforestclassifier__n_estimators=200; total time=  20.5s
# [CV] END randomforestclassifier__max_depth=35, randomforestclassifier__n_estimators=250; total time=  25.8s
# [CV] END randomforestclassifier__max_depth=35, randomforestclassifier__n_estimators=250; total time=  26.0s
# [CV] END randomforestclassifier__max_depth=35, randomforestclassifier__n_estimators=250; total time=  25.9s
# [CV] END randomforestclassifier__max_depth=35, randomforestclassifier__n_estimators=250; total time=  25.9s
# [CV] END randomforestclassifier__max_depth=35, randomforestclassifier__n_estimators=250; total time=  25.6s
# [CV] END randomforestclassifier__max_depth=36, randomforestclassifier__n_estimators=100; total time=  10.3s
# [CV] END randomforestclassifier__max_depth=36, randomforestclassifier__n_estimators=100; total time=  10.4s
# [CV] END randomforestclassifier__max_depth=36, randomforestclassifier__n_estimators=100; total time=  10.4s
# [CV] END randomforestclassifier__max_depth=36, randomforestclassifier__n_estimators=100; total time=  10.4s
# [CV] END randomforestclassifier__max_depth=36, randomforestclassifier__n_estimators=100; total time=  10.2s
# [CV] END randomforestclassifier__max_depth=36, randomforestclassifier__n_estimators=150; total time=  15.4s
# [CV] END randomforestclassifier__max_depth=36, randomforestclassifier__n_estimators=150; total time=  15.5s
# [CV] END randomforestclassifier__max_depth=36, randomforestclassifier__n_estimators=150; total time=  15.5s
# [CV] END randomforestclassifier__max_depth=36, randomforestclassifier__n_estimators=150; total time=  15.6s
# [CV] END randomforestclassifier__max_depth=36, randomforestclassifier__n_estimators=150; total time=  15.4s
# [CV] END randomforestclassifier__max_depth=36, randomforestclassifier__n_estimators=200; total time=  20.5s
# [CV] END randomforestclassifier__max_depth=36, randomforestclassifier__n_estimators=200; total time=  20.8s
# [CV] END randomforestclassifier__max_depth=36, randomforestclassifier__n_estimators=200; total time=  20.6s
# [CV] END randomforestclassifier__max_depth=36, randomforestclassifier__n_estimators=200; total time=  20.8s
# [CV] END randomforestclassifier__max_depth=36, randomforestclassifier__n_estimators=200; total time=  20.4s
# [CV] END randomforestclassifier__max_depth=36, randomforestclassifier__n_estimators=250; total time=  25.6s
# [CV] END randomforestclassifier__max_depth=36, randomforestclassifier__n_estimators=250; total time=  25.9s
# [CV] END randomforestclassifier__max_depth=36, randomforestclassifier__n_estimators=250; total time=  25.7s
# [CV] END randomforestclassifier__max_depth=36, randomforestclassifier__n_estimators=250; total time=  26.0s
# [CV] END randomforestclassifier__max_depth=36, randomforestclassifier__n_estimators=250; total time=  25.5s
# [CV] END randomforestclassifier__max_depth=37, randomforestclassifier__n_estimators=100; total time=  10.3s
# [CV] END randomforestclassifier__max_depth=37, randomforestclassifier__n_estimators=100; total time=  10.5s
# [CV] END randomforestclassifier__max_depth=37, randomforestclassifier__n_estimators=100; total time=  10.4s
# [CV] END randomforestclassifier__max_depth=37, randomforestclassifier__n_estimators=100; total time=  10.5s
# [CV] END randomforestclassifier__max_depth=37, randomforestclassifier__n_estimators=100; total time=  10.3s
# [CV] END randomforestclassifier__max_depth=37, randomforestclassifier__n_estimators=150; total time=  15.4s
# [CV] END randomforestclassifier__max_depth=37, randomforestclassifier__n_estimators=150; total time=  15.6s
# [CV] END randomforestclassifier__max_depth=37, randomforestclassifier__n_estimators=150; total time=  15.4s
# [CV] END randomforestclassifier__max_depth=37, randomforestclassifier__n_estimators=150; total time=  15.5s
# [CV] END randomforestclassifier__max_depth=37, randomforestclassifier__n_estimators=150; total time=  15.4s
# [CV] END randomforestclassifier__max_depth=37, randomforestclassifier__n_estimators=200; total time=  20.5s
# [CV] END randomforestclassifier__max_depth=37, randomforestclassifier__n_estimators=200; total time=  20.7s
# [CV] END randomforestclassifier__max_depth=37, randomforestclassifier__n_estimators=200; total time=  20.7s
# [CV] END randomforestclassifier__max_depth=37, randomforestclassifier__n_estimators=200; total time=  20.9s
# [CV] END randomforestclassifier__max_depth=37, randomforestclassifier__n_estimators=200; total time=  20.6s
# [CV] END randomforestclassifier__max_depth=37, randomforestclassifier__n_estimators=250; total time=  25.6s
# [CV] END randomforestclassifier__max_depth=37, randomforestclassifier__n_estimators=250; total time=  26.0s
# [CV] END randomforestclassifier__max_depth=37, randomforestclassifier__n_estimators=250; total time=  25.7s
# [CV] END randomforestclassifier__max_depth=37, randomforestclassifier__n_estimators=250; total time=  26.3s
# [CV] END randomforestclassifier__max_depth=37, randomforestclassifier__n_estimators=250; total time=  25.7s

# [CV] END randomforestclassifier__max_depth=41, randomforestclassifier__n_estimators=200; total time=  20.9s
# [CV] END randomforestclassifier__max_depth=41, randomforestclassifier__n_estimators=200; total time=  20.6s
# [CV] END randomforestclassifier__max_depth=41, randomforestclassifier__n_estimators=250; total time=  25.8s
# [CV] END randomforestclassifier__max_depth=41, randomforestclassifier__n_estimators=250; total time=  26.1s
# [CV] END randomforestclassifier__max_depth=41, randomforestclassifier__n_estimators=250; total time=  25.9s
# [CV] END randomforestclassifier__max_depth=41, randomforestclassifier__n_estimators=250; total time=  26.2s
# [CV] END randomforestclassifier__max_depth=41, randomforestclassifier__n_estimators=250; total time=  25.7s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=100; total time=  10.3s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=100; total time=  10.7s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=100; total time=  10.6s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=100; total time=  10.5s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=100; total time=  10.3s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=150; total time=  15.5s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=150; total time=  15.6s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=150; total time=  15.6s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=150; total time=  15.7s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=150; total time=  15.4s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=200; total time=  20.7s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=200; total time=  20.9s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=200; total time=  20.7s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=200; total time=  21.0s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=200; total time=  20.7s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=250; total time=  25.7s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=250; total time=  27.4s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=250; total time=  30.0s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=250; total time=  27.4s
# [CV] END randomforestclassifier__max_depth=42, randomforestclassifier__n_estimators=250; total time=  27.3s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=100; total time=  11.7s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=100; total time=  11.0s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=100; total time=  10.5s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=100; total time=  10.6s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=100; total time=  10.3s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=150; total time=  15.5s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=150; total time=  15.6s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=150; total time=  15.5s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=150; total time=  15.7s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=150; total time=  15.4s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=200; total time=  21.0s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=200; total time=  20.9s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=200; total time=  20.6s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=200; total time=  20.9s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=200; total time=  20.6s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=250; total time=  26.5s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=250; total time=  26.4s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=250; total time=  25.8s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=250; total time=  26.1s
# [CV] END randomforestclassifier__max_depth=43, randomforestclassifier__n_estimators=250; total time=  25.7s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=100; total time=  10.3s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=100; total time=  10.5s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=100; total time=  10.4s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=100; total time=  10.5s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=100; total time=  10.2s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=150; total time=  15.4s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=150; total time=  15.6s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=150; total time=  15.6s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=150; total time=  15.7s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=150; total time=  15.6s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=200; total time=  20.5s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=200; total time=  20.9s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=200; total time=  20.8s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=200; total time=  21.0s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=200; total time=  20.7s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=250; total time=  26.3s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=250; total time=  26.1s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=250; total time=  25.8s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=250; total time=  26.2s
# [CV] END randomforestclassifier__max_depth=44, randomforestclassifier__n_estimators=250; total time=  25.8s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=100; total time=  10.6s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=100; total time=  10.5s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=100; total time=  11.4s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=100; total time=  10.4s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=100; total time=  10.3s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=150; total time=  15.3s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=150; total time=  15.5s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=150; total time=  15.5s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=150; total time=  15.7s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=150; total time=  15.4s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=200; total time=  20.5s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=200; total time=  20.9s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=200; total time=  20.5s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=200; total time=  20.9s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=200; total time=  20.6s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=250; total time=  25.7s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=250; total time=  25.8s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=250; total time=  25.6s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=250; total time=  26.1s
# [CV] END randomforestclassifier__max_depth=45, randomforestclassifier__n_estimators=250; total time=  25.9s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=100; total time=  10.2s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=100; total time=  10.4s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=100; total time=  10.4s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=100; total time=  10.5s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=100; total time=  10.2s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=150; total time=  15.4s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=150; total time=  15.6s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=150; total time=  15.4s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=150; total time=  15.7s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=150; total time=  15.4s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=200; total time=  20.5s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=200; total time=  20.7s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=200; total time=  20.5s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=200; total time=  20.9s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=200; total time=  20.5s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=250; total time=  25.6s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=250; total time=  25.9s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=250; total time=  26.3s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=250; total time=  26.8s
# [CV] END randomforestclassifier__max_depth=46, randomforestclassifier__n_estimators=250; total time=  26.2s
# {'randomforestclassifier__max_depth': 31, 'randomforestclassifier__n_estimators': 100}
# CPU times: total: 1h 49min 24s
# Wall time: 1h 43min 47s

# %%
print('Training accuracy:', model_pipe_pca_gs2.score(X_train, y_train))
print('Testing accuracy:',  model_pipe_pca_gs2.score(X_test, y_test))
classification_metrics(model_pipe_pca_gs2)
# Out:
# Training accuracy: 0.967071261923747
# Testing accuracy: 0.8234408221119773
# ------------------------------------------------------------
# [i] CLASSIFICATION REPORT FOR: Test Data
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.86      0.91      0.89      8481
#            1       0.67      0.57      0.62      2807
#
#     accuracy                           0.82     11288
#    macro avg       0.77      0.74      0.75     11288
# weighted avg       0.82      0.82      0.82     11288

# %% [markdown]
# ### GBC

# %%
# Instantiate and fit gradient boosting classifier
model = GradientBoostingClassifier(random_state=42)
model_pipe = make_pipeline(cols_transformer,model)

# %%
model_pipe.fit(X_train, y_train[target].values.ravel())
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('standardscaler',
#                                                   StandardScaler(),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000001D2F5344610>),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000001D2F5336A00>)])),
#                 ('gradientboostingclassifier',
#                  GradientBoostingClassifier(random_state=42))])

# %%
classification_metrics(model_pipe)
# Out:
# ------------------------------------------------------------
# [i] CLASSIFICATION REPORT FOR: Test Data
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91      8560
#            1       0.78      0.61      0.68      2741
#
#     accuracy                           0.86     11301
#    macro avg       0.83      0.78      0.80     11301
# weighted avg       0.86      0.86      0.86     11301

# %% [markdown]
# ### LGBM

# %% [markdown]
# #### Base

# %%
# Instantiate and fit gradient boosting classifier
model = LGBMClassifier(random_state=42)
model_pipe = make_pipeline(cols_transformer,model)
model_pipe.fit(X_train, y_train[target].values.ravel())
classification_metrics(model_pipe)
# Out:
# ------------------------------------------------------------
# [i] CLASSIFICATION REPORT FOR: Test Data
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91      8481
#            1       0.77      0.64      0.70      2807
#
#     accuracy                           0.86     11288
#    macro avg       0.83      0.79      0.81     11288
# weighted avg       0.86      0.86      0.86     11288

# %%
booster_model = model_pipe.named_steps['lgbmclassifier'].booster_

# Get the number of trees in the booster model
num_trees = booster_model.num_trees()

# Calculate the actual depth of the base model
base_model_depth = num_trees // model.n_estimators

print("Actual depth of the base model: ", base_model_depth)
# Out:
# Actual depth of the base model:  1

# %% [markdown]
# #### GS

# %%
param_grid = {
    'lgbmclassifier__learning_rate': [0.1, 0.05, 0.01],  # List of values for learning rate
    'lgbmclassifier__max_depth': list(range(1, 6)),  # List of values for max depth
    'lgbmclassifier__n_estimators': [100, 200, 300]  # List of values for n_estimators
}

# %%
# Instantiate and fit gradient boosting classifier
model = LGBMClassifier(random_state=42)
model_pipe = make_pipeline(cols_transformer,model)
model_pipe_gs = GridSearchCV(model_pipe, param_grid, verbose =2)

# %%
# %%time
model_pipe_gs.fit(X_train, y_train[target].values.ravel())
model_pipe.get_params()
classification_metrics(model_pipe_gs)
# Out:
# Fitting 5 folds for each of 45 candidates, totalling 225 fits
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=200; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=200; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=200; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=200; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=200; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=300; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=200; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=200; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=300; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=200; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=200; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=200; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=200; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=200; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=200; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=300; total time=   0.6s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=300; total time=   0.6s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=300; total time=   0.6s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=300; total time=   0.6s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=300; total time=   0.6s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=200; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=200; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=200; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=200; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=200; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=200; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=300; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=300; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=300; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=300; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=300; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=200; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=200; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=200; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=200; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=200; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=300; total time=   0.6s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=300; total time=   0.6s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=300; total time=   0.6s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=300; total time=   0.6s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=300; total time=   0.8s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=200; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=300; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=300; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=300; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=200; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=200; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=200; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=200; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=200; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=300; total time=   0.7s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=300; total time=   0.6s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=300; total time=   0.7s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=300; total time=   0.6s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=300; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=200; total time=   0.7s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=200; total time=   0.6s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=200; total time=   0.6s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=200; total time=   0.6s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=200; total time=   0.7s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=300; total time=   0.7s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=300; total time=   0.9s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=300; total time=   0.7s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=300; total time=   0.8s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=300; total time=   0.8s
# ------------------------------------------------------------
# [i] CLASSIFICATION REPORT FOR: Test Data
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91      8481
#            1       0.78      0.63      0.70      2807
#
#     accuracy                           0.86     11288
#    macro avg       0.83      0.79      0.81     11288
# weighted avg       0.86      0.86      0.86     11288
# CPU times: total: 11min 7s
# Wall time: 1min 43s

# %%
best_model = model_pipe_gs.best_estimator_

# Retrieve feature importances from the best model
feature_importance = best_model.named_steps['lgbmclassifier'].feature_importances_

# Get feature names from the columns in cols_transformer
feature_names = model_pipe.named_steps['columntransformer'].get_feature_names_out()

# Create a dictionary of feature names and their importance values
feature_importance_dict = dict(zip(feature_names, feature_importance))

# Sort the feature importance dictionary by importance values
sorted_feature_importance_dict = dict(sorted(feature_importance_dict.items(), key=lambda x: x[1], reverse=True))

# Convert the sorted feature importance dictionary to lists
sorted_feature_names = list(sorted_feature_importance_dict.keys())
sorted_feature_importance = list(sorted_feature_importance_dict.values())

# Create a bar plot of feature importance
plt.figure(figsize=(12, 6))
plt.bar(sorted_feature_names, sorted_feature_importance)
plt.title('Feature Importance', fontsize=15)
plt.xlabel('Features', fontsize=12)
plt.ylabel('Importance', fontsize=12)
plt.xticks(rotation=90)
plt.show()

# %%
# Calculate total feature importance value
total_importance = sum(sorted_feature_importance_dict.values())

# Create a combined feature importance dictionary
combined_feature_importance_dict = {}
for feature, importance in sorted_feature_importance_dict.items():
    importance_percent = (importance / total_importance) * 100
    combined_feature_importance_dict[feature] = importance_percent / 100

# Print combined feature importance dictionary
print("Combined Feature Importance:")
for feature, importance in combined_feature_importance_dict.items():
    print(f"'{feature}': {importance:.2f},")
# Out:
# Combined Feature Importance:
# 'standardscaler__net-capital': 0.22,
# 'standardscaler__educational-num': 0.16,
# 'standardscaler__hours-per-week': 0.15,
# 'standardscaler__age': 0.11,
# 'onehotencoder__marital-status_Married-civ-spouse': 0.04,
# 'standardscaler__IsGov': 0.02,
# 'onehotencoder__relationship_Wife': 0.02,
# 'onehotencoder__gender_Female': 0.02,
# 'onehotencoder__occupation_Prof-specialty': 0.01,
# 'onehotencoder__relationship_Unmarried': 0.01,
# 'onehotencoder__occupation_Exec-managerial': 0.01,
# 'onehotencoder__marital-status_Never-married': 0.01,
# 'onehotencoder__relationship_Not-in-family': 0.01,
# 'onehotencoder__occupation_Farming-fishing': 0.01,
# 'onehotencoder__relationship_Husband': 0.01,
# 'onehotencoder__occupation_Adm-clerical': 0.01,
# 'onehotencoder__occupation_Other-service': 0.01,
# 'onehotencoder__relationship_Own-child': 0.01,
# 'onehotencoder__native-country_United-States': 0.01,
# 'onehotencoder__occupation_Machine-op-inspct': 0.01,
# 'onehotencoder__occupation_Sales': 0.01,
# 'onehotencoder__race_Black': 0.01,
# 'onehotencoder__marital-status_Divorced': 0.01,
# 'onehotencoder__occupation_Protective-serv': 0.01,
# 'onehotencoder__occupation_Transport-moving': 0.01,
# 'onehotencoder__native-country_Mexico': 0.01,
# 'onehotencoder__native-country_Philippines': 0.01,
# 'onehotencoder__occupation_Craft-repair': 0.01,
# 'onehotencoder__occupation_Handlers-cleaners': 0.01,
# 'onehotencoder__occupation_Tech-support': 0.01,
# 'onehotencoder__marital-status_Widowed': 0.01,
# 'onehotencoder__relationship_Other-relative': 0.00,
# 'onehotencoder__race_White': 0.00,
# 'onehotencoder__native-country_Columbia': 0.00,
# 'onehotencoder__marital-status_Married-spouse-absent': 0.00,
# 'onehotencoder__race_Asian-Pac-Islander': 0.00,
# 'onehotencoder__native-country_Vietnam': 0.00,
# 'onehotencoder__race_Amer-Indian-Eskimo': 0.00,
# 'onehotencoder__native-country_South': 0.00,
# 'onehotencoder__native-country_Dominican-Republic': 0.00,
# 'onehotencoder__occupation_Priv-house-serv': 0.00,
# 'onehotencoder__native-country_Canada': 0.00,
# 'onehotencoder__native-country_Italy': 0.00,
# 'onehotencoder__native-country_Portugal': 0.00,
# 'onehotencoder__native-country_England': 0.00,
# 'onehotencoder__gender_Male': 0.00,
# 'onehotencoder__native-country_El-Salvador': 0.00,
# 'onehotencoder__native-country_Ireland': 0.00,
# 'onehotencoder__marital-status_Separated': 0.00,
# 'onehotencoder__native-country_China': 0.00,
# 'onehotencoder__native-country_India': 0.00,
# 'onehotencoder__native-country_Japan': 0.00,
# 'onehotencoder__native-country_Trinadad&Tobago': 0.00,
# 'onehotencoder__native-country_France': 0.00,
# 'onehotencoder__native-country_Nicaragua': 0.00,
# 'onehotencoder__native-country_Puerto-Rico': 0.00,
# 'onehotencoder__native-country_Taiwan': 0.00,
# 'onehotencoder__native-country_Thailand': 0.00,
# 'onehotencoder__native-country_Cuba': 0.00,
# 'onehotencoder__native-country_Ecuador': 0.00,
# 'onehotencoder__native-country_Peru': 0.00,
# 'onehotencoder__race_Other': 0.00,
# 'onehotencoder__marital-status_Married-AF-spouse': 0.00,
# 'onehotencoder__occupation_Armed-Forces': 0.00,
# 'onehotencoder__native-country_Cambodia': 0.00,
# 'onehotencoder__native-country_Germany': 0.00,
# 'onehotencoder__native-country_Greece': 0.00,
# 'onehotencoder__native-country_Guatemala': 0.00,
# 'onehotencoder__native-country_Haiti': 0.00,
# 'onehotencoder__native-country_Holand-Netherlands': 0.00,
# 'onehotencoder__native-country_Honduras': 0.00,
# 'onehotencoder__native-country_Hong': 0.00,
# 'onehotencoder__native-country_Hungary': 0.00,
# 'onehotencoder__native-country_Iran': 0.00,
# 'onehotencoder__native-country_Jamaica': 0.00,
# 'onehotencoder__native-country_Laos': 0.00,
# 'onehotencoder__native-country_Outlying-US(Guam-USVI-etc)': 0.00,
# 'onehotencoder__native-country_Poland': 0.00,
# 'onehotencoder__native-country_Scotland': 0.00,
# 'onehotencoder__native-country_Yugoslavia': 0.00,

# %%
# Calculate total feature importance value
total_importance = sum(feature_importance_dict.values())

# Create a combined feature importance dictionary
combined_feature_importance_dict = {}
for feature, importance in sorted_feature_importance_dict.items():
    # Extract the original feature/column name from the columntransformer feature name
    original_feature_name = feature.split('__')[1]  # Assumes columntransformer separator is '__'
    prefix = original_feature_name.split('_')[0]  # Extract prefix from original feature name
    if prefix not in combined_feature_importance_dict:
        combined_feature_importance_dict[prefix] = 0
    combined_feature_importance_dict[prefix] += (importance / total_importance)

# Sort combined feature importance dictionary in descending order
sorted_combined_feature_importance_dict = dict(sorted(combined_feature_importance_dict.items(), key=lambda x: x[1], reverse=True))

# Print combined feature importance dictionary in descending order
print("Combined Feature Importance (Descending Order):")
for feature, importance in sorted_combined_feature_importance_dict.items():
    print(f"'{feature}': {importance:.2f},")
# Out:
# Combined Feature Importance (Descending Order):
# 'net-capital': 0.22,
# 'educational-num': 0.16,
# 'hours-per-week': 0.15,
# 'age': 0.11,
# 'occupation': 0.10,
# 'relationship': 0.07,
# 'marital-status': 0.06,
# 'native-country': 0.06,
# 'IsGov': 0.02,
# 'race': 0.02,
# 'gender': 0.02,

# %%
sorted_combined_feature_names = list(sorted_combined_feature_importance_dict.keys())
sorted_combined_feature_importance = list(sorted_combined_feature_importance_dict.values())

plt.figure(figsize=(12, 6))
plt.bar(sorted_combined_feature_names, sorted_combined_feature_importance)
plt.title('Combined Feature Importance', fontsize=15)
plt.xlabel('Features', fontsize=12)
plt.ylabel('Importance', fontsize=12)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Weighted

# %%
# Instantiate and fit gradient boosting classifier
model = LGBMClassifier(random_state=42, class_weight='balanced')
model_pipe = make_pipeline(cols_transformer,model)
model_pipe.fit(X_train, y_train[target].values.ravel())
classification_metrics(model_pipe)
# Out:
# ------------------------------------------------------------
# [i] CLASSIFICATION REPORT FOR: Test Data
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.95      0.82      0.88      8481
#            1       0.61      0.86      0.71      2807
#
#     accuracy                           0.83     11288
#    macro avg       0.78      0.84      0.80     11288
# weighted avg       0.86      0.83      0.84     11288

# %%
model_pipe_gs = GridSearchCV(model_pipe, param_grid, verbose =2)

# %%
# %%time
model_pipe_gs.fit(X_train, y_train[target].values.ravel())
classification_metrics(model_pipe_gs)
# Out:
# Fitting 5 folds for each of 45 candidates, totalling 225 fits
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=100; total time=   0.1s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=200; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=200; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=200; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=200; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=200; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=200; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=200; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=200; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=200; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=200; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=200; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=200; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=200; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=200; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=300; total time=   0.7s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=300; total time=   0.6s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=300; total time=   0.6s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=300; total time=   0.6s
# [CV] END lgbmclassifier__learning_rate=0.1, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=300; total time=   0.6s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=200; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=200; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=200; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=300; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=200; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=200; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=200; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=100; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=200; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=200; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=200; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=200; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=200; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=300; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=300; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=300; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=300; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=300; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=200; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=200; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=200; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=200; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=200; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=300; total time=   0.6s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=300; total time=   0.6s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=300; total time=   0.7s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=300; total time=   0.7s
# [CV] END lgbmclassifier__learning_rate=0.05, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=300; total time=   0.6s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=1, lgbmclassifier__n_estimators=300; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=200; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=2, lgbmclassifier__n_estimators=300; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=100; total time=   0.2s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=200; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=200; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=200; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=200; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=200; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=300; total time=   0.6s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=300; total time=   0.6s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=300; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=300; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=3, lgbmclassifier__n_estimators=300; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=200; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=200; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=200; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=200; total time=   0.6s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=200; total time=   0.7s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=300; total time=   0.8s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=300; total time=   0.7s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=300; total time=   0.8s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=300; total time=   0.7s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=4, lgbmclassifier__n_estimators=300; total time=   0.7s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100; total time=   0.3s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100; total time=   0.4s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=100; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=200; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=200; total time=   0.5s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=200; total time=   0.6s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=200; total time=   0.6s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=200; total time=   0.6s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=300; total time=   0.8s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=300; total time=   0.7s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=300; total time=   0.8s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=300; total time=   0.7s
# [CV] END lgbmclassifier__learning_rate=0.01, lgbmclassifier__max_depth=5, lgbmclassifier__n_estimators=300; total time=   0.8s
# ------------------------------------------------------------
# [i] CLASSIFICATION REPORT FOR: Test Data
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.95      0.82      0.88      8481
#            1       0.61      0.86      0.71      2807
#
#     accuracy                           0.83     11288
#    macro avg       0.78      0.84      0.80     11288
# weighted avg       0.86      0.83      0.84     11288
# CPU times: total: 11min 27s
# Wall time: 1min 48s

# %% [markdown]
# #### SMOTE

# %%
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import make_pipeline as make_sampler_pipeline

# %%
smote = SMOTE()
model = LGBMClassifier(random_state=42)
model_pipe = make_sampler_pipeline(cols_transformer,smote,model)
model_pipe.fit(X_train, y_train[target].values.ravel())
classification_metrics(model_pipe)
# Out:
# ------------------------------------------------------------
# [i] CLASSIFICATION REPORT FOR: Test Data
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.93      0.86      0.89      8560
#            1       0.65      0.79      0.71      2741
#
#     accuracy                           0.84     11301
#    macro avg       0.79      0.82      0.80     11301
# weighted avg       0.86      0.84      0.85     11301

# %% [markdown]
# ### XGBoost

# %%
from xgboost import XGBClassifier
# Out:
# C:\Users\mmenj\anaconda3\envs\dojo-env\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
# Instantiate and fit gradient boosting classifier
model = XGBClassifier(random_state=42)
model_pipe = make_pipeline(cols_transformer,model)
model_pipe.fit(X_train, y_train[target].values.ravel())
classification_metrics(model_pipe)
# Out:
# C:\Users\mmenj\anaconda3\envs\dojo-env\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [23:11:42] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ------------------------------------------------------------
# [i] CLASSIFICATION REPORT FOR: Test Data
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.89      0.94      0.92      8560
#            1       0.77      0.65      0.70      2741
#
#     accuracy                           0.87     11301
#    macro avg       0.83      0.79      0.81     11301
# weighted avg       0.86      0.87      0.86     11301

# %% [markdown]
# ### Logistic Regresssion

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()
model_pipe = make_pipeline(cols_transformer,model)
model_pipe.fit(X_train, y_train[target].values.ravel())
classification_metrics(model_pipe)
# Out:
# C:\Users\mmenj\anaconda3\envs\dojo-env\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ------------------------------------------------------------
# [i] CLASSIFICATION REPORT FOR: Test Data
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.87      0.92      0.90      8560
#            1       0.70      0.59      0.64      2741
#
#     accuracy                           0.84     11301
#    macro avg       0.79      0.75      0.77     11301
# weighted avg       0.83      0.84      0.83     11301

# %% [markdown]
# ### Keras

# %%
# Learning history plotting function
def plot_history(history):
  """Takes a keras model learning history and plots each metric"""
  
  metrics = history.history.keys()
  
  for metric in metrics:
      if not 'val' in metric:
        plt.plot(history.history[f'{metric}'], label=f'{metric}')
        if f'val_{metric}' in metrics:
          plt.plot(history.history[f'val_{metric}'], label=f'val_{metric}')
        plt.legend()
        plt.title(f'{metric}')
        plt.show()

# %%
X_train_proc.shape
# Out:
# (33900, 79)

# %%
# create model architecture
input_dim = X_train_proc.shape[1]

reg_model = Sequential()
 
#start with one layer with as many nodes as features
reg_model.add(Dense(input_dim, input_dim=input_dim, activation='sigmoid'))

reg_model.add(Dense(1, activation='sigmoid'))
 
reg_model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 79)                6320
#
#  dense_9 (Dense)             (None, 1)                 80
#
# =================================================================
# Total params: 6,400
# Trainable params: 6,400
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time

# compile model with additional metrics
reg_model.compile(loss='bce',
                  optimizer='adam',
                  metrics=['accuracy',
                         metrics.Precision(),
                         metrics.Recall()])

history = reg_model.fit(X_train_proc, y_train,
                        validation_data = (X_test_proc, y_test),
                        epochs=100,
                        verbose=1)

# plot learning
plot_history(history)

#make predictions
y_preds = reg_model.predict(X_test_proc)
 
# round the predictions
y_preds = np.round(y_preds)
 
print(classification_report(y_test, y_preds))
 
ConfusionMatrixDisplay.from_predictions(y_test, y_preds, cmap='Blues');
# Out:
# Epoch 1/100
# 1060/1060 [==============================] - 5s 4ms/step - loss: 0.2918 - accuracy: 0.8608 - precision_3: 0.7620 - recall_3: 0.6435 - val_loss: 0.3199 - val_accuracy: 0.8498 - val_precision_3: 0.6985 - val_recall_3: 0.6702
# Epoch 2/100
# 1060/1060 [==============================] - 4s 4ms/step - loss: 0.2915 - accuracy: 0.8611 - precision_3: 0.7604 - recall_3: 0.6481 - val_loss: 0.3180 - val_accuracy: 0.8528 - val_precision_3: 0.7642 - val_recall_3: 0.5688
# Epoch 3/100
# 1060/1060 [==============================] - 4s 4ms/step - loss: 0.2914 - accuracy: 0.8597 - precision_3: 0.7602 - recall_3: 0.6398 - val_loss: 0.3171 - val_accuracy: 0.8541 - val_precision_3: 0.7360 - val_recall_3: 0.6213
# Epoch 4/100
# 1060/1060 [==============================] - 4s 4ms/step - loss: 0.
100
# 1060/1060 [==============================] - 4s 4ms/step - loss: 0.2715 - accuracy: 0.8691 - precision_3: 0.7725 - recall_3: 0.6745 - val_loss: 0.3380 - val_accuracy: 0.8484 - val_precision_3: 0.7008 - val_recall_3: 0.6545
# Epoch 96/100
# 1060/1060 [==============================] - 4s 4ms/step - loss: 0.2714 - accuracy: 0.8702 - precision_3: 0.7745 - recall_3: 0.6776 - val_loss: 0.3385 - val_accuracy: 0.8479 - val_precision_3: 0.7127 - val_recall_3: 0.6246
# Epoch 97/100
# 1060/1060 [==============================] - 4s 4ms/step - loss: 0.2711 - accuracy: 0.8715 - precision_3: 0.7773 - recall_3: 0.6802 - val_loss: 0.3386 - val_accuracy: 0.8474 - val_precision_3: 0.7225 - val_recall_3: 0.6023
# Epoch 98/100
# 1060/1060 [==============================] - 4s 4ms/step - loss: 0.2710 - accuracy: 0.8703 - precision_3: 0.7752 - recall_3: 0.6769 - val_loss: 0.3388 - val_accuracy: 0.8487 - val_precision_3: 0.7045 - val_recall_3: 0.6479
# Epoch 99/100
# 1060/1060 [==============================] - 4s 4ms/step - loss: 0.2709 - accuracy: 0.8710 - precision_3: 0.7745 - recall_3: 0.6820 - val_loss: 0.3392 - val_accuracy: 0.8470 - val_precision_3: 0.7261 - val_recall_3: 0.5928
# Epoch 100/100
# 1060/1060 [==============================] - 4s 4ms/step - loss: 0.2708 - accuracy: 0.8706 - precision_3: 0.7740 - recall_3: 0.6804 - val_loss: 0.3393 - val_accuracy: 0.8468 - val_precision_3: 0.7209 - val_recall_3: 0.6012
# 354/354 [==============================] - 1s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.90      8560
#            1       0.72      0.60      0.66      2741
#
#     accuracy                           0.85     11301
#    macro avg       0.80      0.76      0.78     11301
# weighted avg       0.84      0.85      0.84     11301
#
# CPU times: total: 31min 30s
# Wall time: 7min 9s

# %%
ConfusionMatrixDisplay.from_predictions(y_test, y_preds, cmap='Blues', normalize='true');

# %% [markdown]
# ### first layer relu

# %%
# create model architecture
input_dim = X_train_proc.shape[1]

reg_model = Sequential()
 
#start with one layer with as many nodes as features
reg_model.add(Dense(input_dim, input_dim=input_dim, activation='relu'))

reg_model.add(Dropout(.3))

reg_model.add(Dense(input_dim, input_dim=input_dim, activation='relu'))

reg_model.add(Dropout(.3))

reg_model.add(Dense(1, activation='sigmoid'))
 
reg_model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_17 (Dense)            (None, 79)                6320
#
#  dropout_2 (Dropout)         (None, 79)                0
#
#  dense_18 (Dense)            (None, 79)                6320
#
#  dropout_3 (Dropout)         (None, 79)                0
#
#  dense_19 (Dense)            (None, 1)                 80
#
# =================================================================
# Total params: 12,720
# Trainable params: 12,720
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time

# compile model with additional metrics
reg_model.compile(loss='bce',
                  optimizer='adam',
                  metrics=['accuracy',
                         metrics.Precision(),
                         metrics.Recall()])

history = reg_model.fit(X_train_proc, y_train,
                        validation_data = (X_test_proc, y_test),
                        epochs=100,
                        verbose=1
                        ,callbacks=[EarlyStopping(patience=10)])

# plot learning
plot_history(history)

#make predictions
y_preds = reg_model.predict(X_test_proc)
 
# round the predictions
y_preds = np.round(y_preds)
 
print(classification_report(y_test, y_preds))
 
ConfusionMatrixDisplay.from_predictions(y_test, y_preds, cmap='Blues', normalize='true');
# Out:
# Epoch 1/100
# 1060/1060 [==============================] - 6s 5ms/step - loss: 0.3560 - accuracy: 0.8319 - precision_6: 0.7045 - recall_6: 0.5633 - val_loss: 0.3309 - val_accuracy: 0.8413 - val_precision_6: 0.6930 - val_recall_6: 0.6202
# Epoch 2/100
# Epoch 14/100
# 1060/1060 [==============================] - 5s 5ms/step - loss: 0.3098 - accuracy: 0.8545 - precision_6: 0.7495 - recall_6: 0.6271 - val_loss: 0.3196 - val_accuracy: 0.8533 - val_precision_6: 0.7610 - val_recall_6: 0.5761
# Epoch 15/100
# 1060/1060 [==============================] - 5s 5ms/step - loss: 0.3100 - accuracy: 0.8534 - precision_6: 0.7478 - recall_6: 0.6232 - val_loss: 0.3213 - val_accuracy: 0.8537 - val_precision_6: 0.7509 - val_recall_6: 0.5939
# Epoch 16/100
# 1060/1060 [==============================] - 5s 5ms/step - loss: 0.3072 - accuracy: 0.8553 - precision_6: 0.7552 - recall_6: 0.6220 - val_loss: 0.3204 - val_accuracy: 0.8548 - val_precision_6: 0.7419 - val_recall_6: 0.6155
# Epoch 17/100
# 1060/1060 [==============================] - 5s 5ms/step - loss: 0.3071 - accuracy: 0.8559 - precision_6: 0.7557 - recall_6: 0.6250 - val_loss: 0.3212 - val_accuracy: 0.8561 - val_precision_6: 0.7585 - val_recall_6: 0.5969
# Epoch 18/100
# 1060/1060 [==============================] - 5s 5ms/step - loss: 0.3067 - accuracy: 0.8553 - precision_6: 0.7513 - recall_6: 0.6287 - val_loss: 0.3217 - val_accuracy: 0.8530 - val_precision_6: 0.7400 - val_recall_6: 0.6074
# Epoch 19/100
# 1060/1060 [==============================] - 5s 5ms/step - loss: 0.3066 - accuracy: 0.8566 - precision_6: 0.7556 - recall_6: 0.6292 - val_loss: 0.3220 - val_accuracy: 0.8518 - val_precision_6: 0.7474 - val_recall_6: 0.5874
# Epoch 20/100
# 1060/1060 [==============================] - 5s 5ms/step - loss: 0.3049 - accuracy: 0.8573 - precision_6: 0.7537 - recall_6: 0.6369 - val_loss: 0.3236 - val_accuracy: 0.8536 - val_precision_6: 0.7406 - val_recall_6: 0.6104
# 354/354 [==============================] - 1s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.91      8560
#            1       0.74      0.61      0.67      2741
#
#     accuracy                           0.85     11301
#    macro avg       0.81      0.77      0.79     11301
# weighted avg       0.85      0.85      0.85     11301
#
# CPU times: total: 8min 43s
# Wall time: 1min 46s

# %% [markdown]
# ## Analysis

# %%
def incomeby(column_name,is50plus):
    dfincome = df[df['income'] == is50plus]
    column_counts = dfincome.groupby(column_name).size().reset_index(name='count')
    column_counts = column_counts.sort_values('count', ascending=False)

    fig, ax = plt.subplots(figsize=(20, 10))
    ax = sns.barplot(data=column_counts, x=column_name, y='count', order=column_counts[column_name])
    plt.xticks(rotation=90)  # Rotating x-axis labels for better readability
    ax.set_title(f'{column_name.capitalize()} Counts for Individuals with Income {" > " if is50plus == 1 else " <= "} 50K', fontsize=20, fontweight='bold')
    ax.set_xlabel(column_name.capitalize(), fontsize=15, fontweight='bold')
    ax.set_ylabel('Count', fontsize=15, fontweight='bold')
    plt.show()

# %%
incomeby('occupation', 0)

# %%
incomeby('occupation', 1)

# %%
incomeby('educational-num', 0)

# %%
incomeby('educational-num', 1)

# %%
incomeby('age', 0)

# %%
incomeby('age', 1)

# %%
incomeby('marital-status', 0)

# %%
incomeby('marital-status', 1)
